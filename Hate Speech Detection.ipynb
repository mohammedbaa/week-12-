# %% [markdown]
# #### Advance NLP : Hate Speech detection using Transformers (Deep Learning)
#
#
# Hate Speech Detection using Transformers (Deep Learning)
# Dataset Link (Links to an external site.)
#
# Problem Statement
#
# The term hate speech is understood as any type of verbal, written or behavioural communication that attacks or uses derogatory or discriminatory language against a person or group based on what they are, in other words, based on their religion, ethnicity, nationality, race, colour, ancestry, sex or another identity factor. In this problem, We will take you through a hate speech detection model with Machine Learning and Python.
#
# Hate Speech Detection is generally a task of sentiment classification. So for training, a model that can classify hate speech from a certain piece of text can be achieved by training it on a data that is generally used to classify sentiments. So for the task of hate speech detection model, We will use the Twitter tweets to identify tweets containing  Hate speech.

# %% [markdown]
# #### By :Mohammad Alghani

# %%
# Data Manipulation 
#=====================================
import pandas as pd 
import numpy as np
# Data Visualization  
#=====================================
import matplotlib.pyplot as plt 
import seaborn as sns 
# Nlp 
#=====================================
import nltk
import spacy
import string
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Rejex
#=====================================
import re 
# Tfidf
#=====================================
from sklearn.feature_extraction.text import TfidfVectorizer
# Split the Data
#=====================================
from sklearn.model_selection import train_test_split 
# Word Cloud
#=====================================
from wordcloud import WordCloud 
from wordcloud import STOPWORDS
# Model
#=====================================
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping 
from tensorflow.keras.preprocessing.text import one_hot
#Metreix
#=======================================
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
#Warnings 
#=====================================
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ![ML](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ### Load The Data

# %%
df=pd.read_csv('train_E6oV3lV.csv')

# %%
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
df.tail()
# Out:
#           id  label                                              tweet
# 31957  31958      0  ate @user isz that youuu?ðððððð...
# 31958  31959      0    to see nina turner on the airwaves trying to...
# 31959  31960      0  listening to sad songs on a monday morning otw...
# 31960  31961      1  @user #sikh #temple vandalised in in #calgary,...
# 31961  31962      0                   thank you @user for you follow

# %% [markdown]
# ### <font color = #27C3E5> 1.3: </font> <font color = #41EA46> Data Information</font>

# %% [markdown]
# ####  <font color = Green> 1.3.1: How many numbers of observations and features</font>

# %%
print(f'Number of Observation: {df.shape[0]}')
print(f'Number of Feature: {df.shape[1]}')
# Out:
# Number of Observation: 31962
# Number of Feature: 3

# %% [markdown]
# ####  <font color = Red> 1.3.2: Features that we have in this data</font>

# %%
df.columns
# Out:
# Index(['id', 'label', 'tweet'], dtype='object')

# %% [markdown]
# #### <font color = pink> 1.3.3: Type of Data</font>

# %%
df.dtypes
# Out:
# id        int64
# label     int64
# tweet    object
# dtype: object

# %% [markdown]
# #### <font color=Yellow> 1.3.4: Data Info </font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31962 entries, 0 to 31961
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      31962 non-null  int64
#  1   label   31962 non-null  int64
#  2   tweet   31962 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 749.2+ KB

# %% [markdown]
# #### <font color= Red>1.3.5 Data size </font>

# %%
df.size
# Out:
# 95886

# %% [markdown]
# #### <font color = white> 1.3.6: Predictor and Target Attribute</font>

# %%
text=df.iloc[:,2]
text.head()
# Out:
# 0     @user when a father is dysfunctional and is s...
# 1    @user @user thanks for #lyft credit i can't us...
# 2                                  bihday your majesty
# 3    #model   i love u take with u all the time in ...
# 4               factsguide: society now    #motivation
# Name: tweet, dtype: object

# %%
label=df.iloc[:,1]
label.tail()
# Out:
# 31957    0
# 31958    0
# 31959    0
# 31960    1
# 31961    0
# Name: label, dtype: int64

# %% [markdown]
# #### <font color = white> 1.3.7: Check the Missing Value</font>

# %%
df.isnull().sum()
# Out:
# id       0
# label    0
# tweet    0
# dtype: int64

# %% [markdown]
# #### <font color = white> 1.3.8: Extracting the Target Attribute for Each Class and Visualize </font>

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='label', data=df, palette='viridis')
plt.title('Label Distribution')
plt.xlabel('Label')
plt.ylabel('Count')
plt.show()

# %%
df['tweet_length'] = df['tweet'].apply(len)
plt.figure(figsize=(10, 6))
sns.histplot(df['tweet_length'], kde=True, bins=20, color='skyblue')
plt.title('Tweet Length Distribution')
plt.xlabel('Tweet Length')
plt.ylabel('Frequency')
plt.show()

# %%
# Remove stopwords and punctuations for a clearer word cloud
stop_words = set(stopwords.words('english') + list(string.punctuation))

def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
    return ' '.join(tokens)

df['processed_tweet'] = df['tweet'].apply(preprocess_text)

# Most Common Words in Non-Hateful Tweets
all_words_non_hateful = ' '.join(df[df['label'] == 0]['processed_tweet'])
word_counts_non_hateful = pd.Series(all_words_non_hateful.split()).value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=word_counts_non_hateful.values, y=word_counts_non_hateful.index, palette='viridis')
plt.title('Top 10 Most Common Words in Non-Hateful Tweets')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.show()

# Most Common Words in Hateful Tweets
all_words_hateful = ' '.join(df[df['label'] == 1]['processed_tweet'])
word_counts_hateful = pd.Series(all_words_hateful.split()).value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=word_counts_hateful.values, y=word_counts_hateful.index, palette='magma')
plt.title('Top 10 Most Common Words in Hateful Tweets')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.show()

# %%
hate_speech=df[df['label']==1].shape[0]
free_speech=df[df['label']==0].shape[0]
print('Hate speech=',hate_speech)
print('Free speech=',free_speech)
# Out:
# Hate speech= 2242
# Free speech= 29720

# %%
speech=[hate_speech,free_speech]
label=['Hate Speech','Free Speech']

plt.pie(speech,labels=label,shadow=True,wedgeprops={'edgecolor':'black'},autopct="%1.1f%%",startangle=90,colors=['red','green'])
plt.tight_layout()
plt.show()

# %% [markdown]
# <img style="width:70px; height:70px; float:left;" src="https://thumbs.gfycat.com/DisgustingSpiffyIguana-size_restricted.gif"><img style="width:70px; height:70px; float:right;" src="https://thumbs.gfycat.com/DisgustingSpiffyIguana-size_restricted.gif"><h2 style="background-color:black; color:white; text-align:center;"><b><i>Part 2: Data Preprocessing</i></b></h2>
#
# In this part, we did data preprocessing. firstly, we did text cleaning with the help of Regular Expression and then we apply preprocessing operations like Tokenization to make a token of each sentence, then remove stop words like "the", "a", "at" etc and then apply stemming to reducing a word to its word stem. After that, we apply the IF-IDF model for feature extraction and we took 2000 most frequent words from dictionaries. In the end, we split our data for training and testing. And ratio for training and testing is 0.8 and 0.2 respectively.
#
# ### <font color = #27C3E5> 2.1: </font> <font color = #41EA46> Text Cleaning </font>
# > <b>Lowercase <br> Remove Punctuation <br> Remove Urls <br> Removing @tags <br> Remove Special Characters </b>

# %% [markdown]
# ![Machine Learning Project](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# #### <font color=Green> 2.1.1 Lower Case </font>

# %%
# def lower_case(text):
#     return text.lower()

# df['tweet']=df['tweet'].apply(lower_case)

# %% [markdown]
# #### <font color=Green> 2.1.2 Remove Punctuation </font>

# %%
# def remove_punct(text):
#     return text.translate(str.maketrans('','',string.punctuation))

# df['tweet']=df['tweet'].apply(remove_punct)

# %% [markdown]
# #### <font color = Green>2.1.3: Remove URLs </font>

# %%
# def remove_punct_and_url(text):
#     text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
#     text = text.translate(str.maketrans('', '', string.punctuation))
#     return text


# df['tweet'] = df['tweet'].apply(remove_punct_and_url)

# %% [markdown]
# #### <font color = Green>2.1.4: Remove Tags </font>

# %%
# def remove_tag(text):
#     newtext=re.sub(r'@[A-Za-z0-9]+',"",text)
#     return newtext

# df['tweet']=df['tweet'].apply(remove_tag)

# %% [markdown]
# #### <font color = Green>2.1.5: Remove Special Characters </font>

# %%
# def remove_special(text):
#     return " ".join (e for e in text.split() if e.isalnum())

# df['tweet']=df['tweet'].apply(remove_special)

# %% [markdown]
# ### <font color = #27C3E5> 2.2: </font> <font color = #41EA46>  Preprocessing Operations </font>
# > <b>Tokenizing <br> Removing Stop Words <br> Lemmatization <b> <br> WordCloud </b>

# %% [markdown]
# #### <font color = Green>2.2.1: Tokenizing

# %%
# def tokenize(text):
#     text=word_tokenize(text)
#     return text 

# df['tweet']=df['tweet'].apply(tokenize)

# %% [markdown]
# #### <font color = Red>2.2.2: Removing StopWords

# %%
# def remove_stop(text):
#     text=[i for i in text if not i in stopwords.words('english')]
#     return text


# df['tweet']=df['tweet'].apply(remove_stop)

# %% [markdown]
# #### <font color = Green>2.2.3: Lemmatization

# %%
# nltk.download('wordnet')
# def Lemmatize(text):
#     word_lem=WordNetLemmatizer()
#     text=[word_lem.lemmatize(token)  for token in text]
#     return text 

# df['tweet'] = df['tweet'].apply(Lemmatize)

# %%
X=df.drop(columns=['label'],axis=1)
y=df['label']
messages=X.copy()

# %%
nltk.download('stopwords')
ps=WordNetLemmatizer()
corpus=[]
for i in range(len(messages)):
  text=re.sub('[^a-zA-Z]',' ',messages['tweet'][i])
  text=text.lower()
  text=text.split() ## Get word by word

  text=[ps.lemmatize(word) for word in text if not word in stopwords.words('english')]
  text=' '.join(text)
  corpus.append(text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# #### <font color = Red>2.2.4: WordCloud

# %% [markdown]
# #### For The Hate Speech

# %%
hate_speech=df[df['label']==1]
comment_words=''
stopwords=set(STOPWORDS)
for val in hate_speech.tweet:
    val=str(val)
    tokens=val.split()
    for i in range(len(tokens)):
        tokens[i]=tokens[i].lower()
    comment_words+=" ".join(tokens)+" "

wordcloud=WordCloud(width=800,height=800,background_color='white',stopwords=stopwords,min_font_size=10).generate(comment_words)

plt.figure(figsize=(8,8),facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# #### For The Free Speech

# %%
free_speech = df[df['label'] == 1]   
comment_words = ''
stopwords = set(STOPWORDS)
for val in free_speech.tweet:
     
    #typecaste each val to string
    val = str(val)
 
    #split the value
    tokens = val.split()
     
    #Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
df['tweet'][0]
# Out:
# ' @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run'

# %% [markdown]
# ### <font color = #27C3E5> 2.3: </font> <font color = #41EA46>  Feature Extraction </font>
# <font color = Red><b>2.3.1: Embadding Way  </b> <br>

# %%
### First we do one hot encoding 
voc_size=5000
corpus=df['tweet'].astype(str)
one_hot_rep=[one_hot(words,voc_size) for words in corpus]

# %%
one_hot_rep
# Out:
# [[3310,
#   4933,
#   2119,
#   2766,
#   1467,
#   232,
#   2995,
#   1467,
#   4109,
#   4126,
#   3109,
#   3252,
#   3356,
#   248,
#   3524,
#   3356,
#   4368,
#   1016],
#  [3310,
#   3310,
#   1681,
#   4081,
#   3367,
#   4959,
#   3466,
#   525,
#   4972,
#   5,
#   2945,
#   1310,
#   4213,
#   2122,
#   3954,
#   216,
#   1564,
#   4710,
#   455],
#  [1668, 883, 4176],
#  [1076, 3466, 1114, 4556, 3483, 2401, 4556, 3436, 2149, 4100, 216, 823, 1915],
#  [4838, 3140, 931, 1860],
#  [2023,
#   2023,
#   3450,
#   1110,
#   898,
#   2995,
#   4872,
#   1861,
#   1207,
#   2945,
#   4372,
#   2224,
#   2995,
#   781,
#   2285,
#   4933,
#   2945,
#   1948,
#   3613,
#   3697],
#  [3310, 1937, 4795, 3310, 3310, 3310, 3310, 3310, 3310, 3310, 3475],
#  [2149,
#   228,
#   1138,
#   2050,
#   1467,
#   2149,
#   2050,
#   4081,
#   4399,
#   2616,
#   525,
#   3163,
#   1730,
#   2099,
#   841,
#   1138,
#   4399,
#   3614,
#   1021,
#   832,
#   3656,
#   2326],
#  [2870, 4366, 1114, 2149, 1241, 1051, 3932, 3238, 4174, 3567, 1034],
#  [3310, 3310, 915, 577, 4927, 2124, 4109, 3512],
#  [581,
#   2835,
#   1501,
#   3384,
#   1143,
#   583,
#   652,
#   1506,
#   821,
#   619,
#   2023,
#   2145,
#   619,
#   2447,
#   216,
#   608,
#   192,
#   2822,
#   1494,
#   1151],
#  [2870, 4087, 4109, 4126, 1029, 3546, 2918, 4811, 1424, 4126, 579, 2564, 1114],
#  [3466, 1948, 2145, 2210, 3196, 2981, 854, 2740, 2897],
#  [3310, 3078, 3151, 1056, 2965, 1138, 4969, 2149, 3121, 672, 850, 2797],
#  [1333, 882, 216, 3291, 2979, 1743, 4161, 2173, 4161],
#  [2817, 3303, 1467, 1722, 4148, 3303, 2303, 3364],
#  [3466, 2652, 4827, 4081, 2351, 2119, 1826, 4827, 504],
#  [3579, 4983, 4611, 864],
#  [2278,
#   1855,
#   2291,
#   1852,
#   3436,
#   2999,
#   3283,
#   4204,
#   3310,
#   3310,
#   3371,
#   4673,
#   1332],
#  [2018, 2870, 3436, 4996, 4346, 4785, 4087, 3885, 4361, 3132, 2904],
#  [1310,
#   1332,
#   4801,
#   200,
#   4081,
#   1431,
#   3190,
#   1452,
#   3716,
#   3947,
#   3387,
#   2133,
#   2118,
#   2037,
#   2393,
#   2745,
#   1709,
#   4473,
#   2128,
#   3596,
#   2845,
#   1506,
#   3613],
#  [3764, 3999, 3928, 2901, 4165, 243, 2235, 605, 1772],
#  [3002,
#   3132,
#   2149,
#   123,
#   3134,
#   3911,
#   3866,
#   2310,
#   830,
#   2124,
#   2149,
#   3765,
#   4100,
#   2145,
#   2297,
#   343,
#   3903,
#   1063,
#   343],
#  [3310, 3310, 1744, 2640, 3466, 2652, 2119, 3463, 3716, 1744],
#  [3310,
#   3570,
#   1201,
#   2145,
#   3196,
#   2951,
#   4544,
#   367,
#   3814,
#   3310,
#   3310,
#   3310,
#   3310,
#   3310],
#  [752, 4947, 579, 2786, 3099, 4081, 4384, 2259, 2206, 2897, 1114],
#  [3310,
#   3436,
#   1852,
#   4933,
#   598,
#   1467,
#   186,
#   2431,
#   216,
#   247,
#   4612,
#   4958,
#   711,
#   1114,
#   3683],
#  [2870,
#   2731,
#   2119,
#   4743,
#   2157,
#   1855,
#   2149,
#   3017,
#   3132,
#   2149,
#   4028,
#   1018,
#   1995],
#  [3134, 989, 123, 3310, 1516],
#  [1492,
#   1332,
#   4877,
#   2145,
#   4506,
#   2145,
#   1505,
#   2119,
#   346,
#   2426,
#   2995,
#   2701,
#   1982,
#   3029,
#   1396,
#   185,
#   1332,
#   4087,
#   3281,
#   2145,
#   3197,
#   2867,
#   1864,
#   1899,
#   1029],
#  [3466,
#   1505,
#   1675,
#   2731,
#   2119,
#   706,
#   2145,
#   2821,
#   4081,
#   2119,
#   3446,
#   3879,
#   3466,
#   1452,
#   656,
#   1730,
#   2995,
#   4021,
#   4502,
#   1551,
#   2145,
#   3961,
#   1333,
#   1429],
#  [2035, 4100, 2969, 3885, 1231, 2955, 3880, 3310, 3310, 3310, 3310],
#  [3310,
#   1899,
#   2145,
#   2149,
#   4551,
#   4426,
#   2835,
#   1110,
#   2133,
#   2052,
#   3369,
#   2037,
#   447,
#   11,
#   1864,
#   1105,
#   2995,
#   825,
#   1855,
#   4124],
#  [3716,
#   1452,
#   2119,
#   789,
#   494,
#   2715,
#   2145,
#   3131,
#   1472,
#   2282,
#   2156,
#   582,
#   4081,
#   854,
#   2792,
#   2225],
#  [2124,
#   2838,
#   2099,
#   216,
#   2149,
#   4705,
#   4919,
#   3457,
#   2961,
#   987,
#   4537,
#   4021,
#   2272,
#   1417,
#   521],
#  [4028,
#   4991,
#   343,
#   4611,
#   1037,
#   142,
#   883,
#   4991,
#   2995,
#   4611,
#   1037,
#   3433,
#   3716,
#   725,
#   4611,
#   4701,
#   3716,
#   2145,
#   3021,
#   1902],
#  [312, 1556, 4175, 3093],
#  [3310,
#   2131,
#   2987,
#   4665,
#   4253,
#   3719,
#   4215,
#   3716,
#   3436,
#   2299,
#   4669,
#   4725,
#   4064],
#  [2214,
#   748,
#   1130,
#   2023,
#   483,
#   216,
#   2149,
#   295,
#   3445,
#   2995,
#   3716,
#   626,
#   3622,
#   2870,
#   3987,
#   4109,
#   3969],
#  [3466, 2652, 4827, 4081, 291, 4827, 504],
#  [4933,
#   4611,
#   3493,
#   2358,
#   2119,
#   4648,
#   391,
#   4412,
#   3622,
#   1855,
#   4081,
#   4028,
#   2700,
#   1751],
#  [3749,
#   2965,
#   2119,
#   4184,
#   1110,
#   1467,
#   789,
#   4109,
#   2278,
#   3203,
#   2145,
#   2659,
#   3961,
#   2222,
#   2358,
#   1110,
#   4933,
#   2149,
#   4564,
#   4308,
#   2999,
#   2552],
#  [3613, 1467, 4947, 1937, 4132, 4910, 1493, 1975, 123, 3961],
#  [3196,
#   583,
#   670,
#   2149,
#   3994,
#   1668,
#   2018,
#   3310,
#   1668,
#   4636,
#   2210,
#   4611,
#   4021,
#   3765,
#   628],
#  [1939, 1991, 2810, 379, 4533, 2188, 3121, 2597, 2810, 1644],
#  [3466, 2652, 2556, 3466, 2652, 504, 2059],
#  [1076, 3466, 1114, 4556, 3483, 2401, 4556, 3436, 2149, 4100, 216, 823, 1915],
#  [1478, 1612, 2995, 987, 694, 3591],
#  [3514, 1510, 2379],
#  [2149, 4912, 1312, 1730, 4947, 1467, 1709, 2133, 4611, 4087, 2331, 1034],
#  [691, 4299, 2583, 2023, 1517, 2149, 3846, 1816, 1346, 2191],
#  [4081,
#   2022,
#   1668,
#   2870,
#   2547,
#   2022,
#   2119,
#   2921,
#   2185,
#   3310,
#   1004,
#   1668,
#   2159,
#   2870,
#   1114,
#   4611,
#   1877],
#  [2416, 2145, 849, 2906, 2149, 1353, 4081, 2149, 36, 4100, 3310],
#  [3310, 2047, 2149, 3605, 1033, 2851],
#  [2609, 4611, 3468, 4498, 1114, 3716, 1646, 2511, 3753, 1995, 2189, 3418],
#  [2119, 71, 1855, 185, 4034, 577, 3955, 1855, 539, 827, 4881],
#  [3310, 4480, 4207, 4814, 1114, 2150],
#  [3134, 112, 123, 1659, 205, 4146, 4017, 123, 205, 2283, 836, 4534],
#  [3310, 3247, 4070, 2401, 4021, 4074, 4588, 3247, 1586, 1962, 3325, 523],
#  [2149, 3765, 1467, 577, 2981, 98, 4289, 655, 499],
#  [3134,
#   2906,
#   61,
#   2428,
#   592,
#   4604,
#   2114,
#   2145,
#   4087,
#   3132,
#   3604,
#   238,
#   61,
#   4604],
#  [3034, 2251, 3418, 1003, 1207, 2965, 4456, 3283, 3310, 3032, 3883, 962],
#  [2870, 4087, 2583, 2145, 1364, 1985, 2814, 2925, 2833],
#  [391, 1443, 3498, 3196, 1117],
#  [3310,
#   3196,
#   429,
#   2673,
#   3466,
#   87,
#   2731,
#   2145,
#   2693,
#   883,
#   1711,
#   3222,
#   4216,
#   2236,
#   2731,
#   1894,
#   2022,
#   4296,
#   1467,
#   1657,
#   3903,
#   1171,
#   3196,
#   1190],
#  [3310, 3466, 2652, 4109, 1417, 3132, 4611, 3, 931, 1879],
#  [3466, 271, 3260, 3911, 2099, 3953, 232, 2124, 1768, 3924, 989, 123],
#  [4927, 2037, 2945, 4087, 2659, 2018, 3134, 2269, 2363],
#  [3239,
#   4097,
#   2378,
#   525,
#   1505,
#   747,
#   1946,
#   3335,
#   2999,
#   4893,
#   3236,
#   2995,
#   2136,
#   435,
#   2574],
#  [346, 312, 2149, 500, 977, 3405, 1119, 995, 2034, 2072],
#  [3310, 4983, 4611, 4347, 2893, 4537, 4021, 1506, 4422, 2273, 621],
#  [435, 1862, 78, 1505, 4122, 553, 737, 216, 3941],
#  [4109,
#   188,
#   4843,
#   3610,
#   216,
#   2020,
#   36,
#   1029,
#   1542,
#   2995,
#   931,
#   2898,
#   1855,
#   2119,
#   690,
#   2050,
#   1594,
#   712],
#  [3310,
#   109,
#   1037,
#   3021,
#   1349,
#   4081,
#   2149,
#   2125,
#   3132,
#   2149,
#   1217,
#   4021,
#   3241,
#   1467,
#   3099,
#   2119,
#   4144,
#   1676,
#   2467,
#   109,
#   1080,
#   1104],
#  [779, 3196, 36, 2938, 4031],
#  [3066, 99, 3524, 2206, 127, 898, 4218, 2906, 653, 2525],
#  [3310, 1257, 343, 527, 3310, 3893, 3310, 3310, 3310],
#  [3310,
#   87,
#   4097,
#   1332,
#   4611,
#   2128,
#   3444,
#   1332,
#   811,
#   579,
#   3310,
#   3472,
#   2495,
#   1257],
#  [3310,
#   3310,
#   4611,
#   346,
#   3961,
#   2659,
#   1505,
#   3885,
#   4238,
#   577,
#   854,
#   2633,
#   1861,
#   898,
#   2995,
#   4296,
#   421],
#  [4339,
#   4611,
#   1505,
#   2145,
#   3761,
#   2119,
#   2110,
#   2910,
#   2145,
#   3761,
#   2149,
#   1879,
#   4622,
#   4155,
#   2149],
#  [1730, 2099, 763, 486, 263, 3310, 3310],
#  [3310,
#   2649,
#   824,
#   3234,
#   4130,
#   3310,
#   2145,
#   2480,
#   1119,
#   785,
#   4813,
#   3637,
#   3310,
#   3588],
#  [553, 2149, 4426, 3133, 3903, 373, 2145, 72, 3117, 3524, 3561],
#  [1771,
#   2119,
#   3670,
#   3959,
#   3132,
#   2736,
#   4983,
#   4611,
#   525,
#   3483,
#   3716,
#   216,
#   2401,
#   4611,
#   3670,
#   4869,
#   4778,
#   3210,
#   2149,
#   18,
#   4847,
#   4587,
#   1037,
#   1948,
#   23],
#  [4972, 2149, 2282, 3132, 883, 2208, 2145, 1036, 883, 3339, 3774, 3766, 2150],
#  [3976, 2659, 323, 2447, 1285, 2145, 1923],
#  [2965, 216, 2119, 124, 2037, 1330, 4747, 4611, 1505, 1333, 4239, 3206, 4319],
#  [2583,
#   2145,
#   2075,
#   447,
#   2401,
#   1862,
#   508,
#   2995,
#   1862,
#   4534,
#   1136,
#   4267,
#   4081,
#   2149,
#   2563,
#   4717,
#   4968,
#   4811,
#   965],
#  [931,
#   1855,
#   494,
#   818,
#   2906,
#   3453,
#   1855,
#   343,
#   334,
#   3466,
#   3493,
#   1948,
#   2145,
#   2210,
#   481,
#   3436,
#   2149,
#   2984,
#   1467,
#   1730],
#  [803, 2149, 1862, 1021, 3132, 3310, 1855, 3310],
#  [3310,
#   233,
#   931,
#   1937,
#   2119,
#   793,
#   3668,
#   2995,
#   3549,
#   2426,
#   3150,
#   1413,
#   3310,
#   94,
#   1516],
#  [4935, 3978, 3874, 1332, 3021],
#  [2136,
#   4950,
#   3196,
#   3420,
#   1284,
#   4081,
#   3196,
#   2760,
#   4109,
#   1037,
#   3961,
#   1084,
#   2906,
#   3310,
#   2272,
#   216,
#   308,
#   774,
#   4291],
#  [1191,
#   1722,
#   2022,
#   1454,
#   2999,
#   4387,
#   3220,
#   4034,
#   3356,
#   965,
#   4081,
#   72,
#   4600,
#   2870,
#   3758,
#   56,
#   579,
#   2149,
#   3637,
#   1953,
#   1598],
#  [3364,
#   4893,
#   4021,
#   1955,
#   734,
#   2145,
#   47,
#   4267,
#   2906,
#   61,
#   4600,
#   4299,
#   61,
#   33,
#   3132,
#   4716,
#   1598,
#   3310],
#  [3310,
#   1240,
#   1066,
#   2564,
#   2099,
#   4253,
#   123,
#   1240,
#   1948,
#   2145,
#   4256,
#   4611,
#   572,
#   3466,
#   1310,
#   3163,
#   2099,
#   2124,
#   921,
#   2683,
#   2089,
#   2840],
#  [1076, 3466, 1114, 4556, 3483, 2401, 4556, 3436, 2149, 4100, 216, 823, 1915],
#  [1351, 2351, 185, 3947, 1684, 2820, 1938],
#  [2697, 1855, 2099, 2697, 123, 1956, 379, 3758],
#  [535, 2870, 4232, 3029, 357, 1948, 577, 738, 3690, 1280, 1534],
#  [3613, 4087, 4969, 1491, 2623, 1450, 4267, 3613],
#  [3477,
#   421,
#   1855,
#   3121,
#   2145,
#   540,
#   323,
#   2149,
#   1029,
#   299,
#   2149,
#   2859,
#   3953,
#   2119,
#   1676,
#   296,
#   1957,
#   2995,
#   3436,
#   3109,
#   2996,
#   1452,
#   4745,
#   1730,
#   3488],
#  [3310, 3310, 3310, 3310, 3885, 3549, 931, 921, 716, 679],
#  [581,
#   500,
#   3629,
#   3958,
#   2701,
#   2140,
#   4049,
#   4917,
#   2145,
#   1118,
#   3471,
#   994,
#   4609,
#   192,
#   2822,
#   1494,
#   1151],
#  [2893, 2145, 1233, 4795],
#  [3466, 2652, 4827, 4081, 346, 538, 4827, 504],
#  [3466,
#   3988,
#   2128,
#   3885,
#   2018,
#   3196,
#   2067,
#   2999,
#   2149,
#   868,
#   2099,
#   962,
#   1467,
#   2314,
#   2995,
#   2149,
#   868,
#   2099,
#   2119,
#   3911,
#   4097,
#   2191,
#   2659],
#  [2659, 4950, 2883, 1506, 3310, 525, 648, 2145, 4413, 2026, 834, 3441, 817],
#  [2870, 3987, 4109, 2145, 3961, 4034, 4081, 651, 89, 3836, 1899, 3283, 3310],
#  [3310, 2136, 2136, 2136, 1630, 2185],
#  [4958, 2522, 3765, 4482, 3274, 1857, 2665, 4958, 1129],
#  [3310,
#   4927,
#   3885,
#   643,
#   216,
#   2119,
#   3375,
#   2099,
#   1090,
#   30,
#   3472,
#   3903,
#   478,
#   1467,
#   1730,
#   2282,
#   4348,
#   418],
#  [4253, 3132, 3196, 3731, 3549, 3281, 1686, 931, 1601, 1681, 2145, 4027, 508],
#  [4943, 3400, 3457, 128, 635, 2009, 1364, 843, 579, 3310],
#  [3310,
#   4034,
#   3885,
#   3310,
#   2046,
#   3121,
#   4081,
#   2965,
#   18,
#   3310,
#   3310,
#   3310,
#   3310,
#   2085],
#  [581, 103, 2149, 3059, 3132, 2085, 3912, 4177, 192, 2822, 1494, 1151],
#  [3638, 2556, 1997, 4251, 3132, 4915, 3766, 1467, 3774],
#  [1076, 3466, 1114, 4556, 3483, 2401, 4556, 3436, 2149, 4100, 216, 823, 1915],
#  [2416, 2145, 61, 4266, 4098, 4170, 2195, 2099, 791, 1783, 1114],
#  [2385, 1683, 2784, 3466, 4361, 3716, 4259, 2511, 330],
#  [1492,
#   2122,
#   3132,
#   2557,
#   4233,
#   2959,
#   33,
#   2995,
#   4983,
#   343,
#   2119,
#   3541,
#   4551,
#   524],
#  [203,
#   2004,
#   1526,
#   3461,
#   4978,
#   4804,
#   2004,
#   1526,
#   3461,
#   4978,
#   2149,
#   2004,
#   1526,
#   2025,
#   216,
#   2994,
#   3610,
#   1397],
#  [3310, 3310, 1178, 1842, 4804, 2119, 4333, 737, 1492, 3885, 4109, 188],
#  [3134, 855, 628, 4082, 4081, 2149, 1638, 1638, 1413],
#  [1855, 3466, 2693, 4611, 2300, 4985, 2061, 513],
#  [183, 2545, 4266, 1699, 1015, 3502],
#  [3620, 1564, 4190, 223, 3663, 617, 1136, 2126, 1852, 4894],
#  [3764,
#   216,
#   2149,
#   4936,
#   3996,
#   2659,
#   4807,
#   123,
#   3734,
#   4246,
#   4087,
#   3214,
#   4994,
#   1665,
#   4627,
#   2932],
#  [995,
#   1862,
#   3015,
#   216,
#   2149,
#   2341,
#   4081,
#   175,
#   3197,
#   2945,
#   4087,
#   4109,
#   1035,
#   2016,
#   3015],
#  [3310,
#   4447,
#   3596,
#   1754,
#   3420,
#   1855,
#   785,
#   890,
#   3965,
#   3420,
#   1452,
#   4235,
#   4447,
#   1467,
#   4970,
#   3666,
#   831,
#   1893,
#   931],
#  [4921, 4361, 216, 3875, 388, 4365, 3091, 1534, 4344, 1114, 3006, 2644],
#  [1332,
#   1984,
#   3903,
#   3477,
#   4216,
#   2119,
#   3359,
#   4366,
#   2945,
#   3021,
#   4109,
#   4216,
#   3477,
#   3953,
#   382,
#   3903,
#   1034],
#  [3466,
#   2961,
#   2145,
#   1336,
#   2119,
#   734,
#   2145,
#   1003,
#   3196,
#   4100,
#   4109,
#   4611,
#   4087,
#   3885,
#   1066,
#   1855,
#   3196,
#   2208,
#   175,
#   2859,
#   3428,
#   1034],
#  [4645, 4935, 919, 4132, 3449, 3662, 2099, 3376],
#  [2750,
#   4996,
#   2149,
#   4992,
#   435,
#   1156,
#   2995,
#   3350,
#   1522,
#   3697,
#   3183,
#   2129,
#   3678,
#   735,
#   689],
#  [13,
#   4226,
#   175,
#   2987,
#   3840,
#   3624,
#   4243,
#   4034,
#   3696,
#   2409,
#   2119,
#   4456,
#   4983,
#   4556,
#   3987,
#   2893,
#   2145,
#   3483,
#   3716,
#   2416],
#  [1802, 2724, 3037, 4294, 3404, 1043, 1153, 4732],
#  [3310,
#   1247,
#   2241,
#   2298,
#   605,
#   4837,
#   1467,
#   2145,
#   3758,
#   883,
#   4947,
#   2145,
#   3961,
#   3996,
#   3436,
#   2099,
#   3256,
#   4947,
#   1467,
#   2651,
#   2382,
#   321],
#  [3134, 1668, 1361, 1779, 2119, 4743, 1902, 2995, 3010, 4842, 3305, 3710],
#  [435,
#   2330,
#   16,
#   3395,
#   1923,
#   4267,
#   2145,
#   2149,
#   2987,
#   3840,
#   1492,
#   1332,
#   2133,
#   3987,
#   1584,
#   2119,
#   1638,
#   4506,
#   216,
#   2020],
#  [3310, 459, 1009, 4081, 1862, 911, 109, 2129, 1009, 887],
#  [2161, 3649, 4902, 3310, 3570, 887, 4758, 2879, 711, 3765],
#  [581,
#   1014,
#   3629,
#   3216,
#   2149,
#   3638,
#   994,
#   4457,
#   2906,
#   619,
#   3684,
#   192,
#   2822,
#   1494,
#   1151],
#  [3310,
#   4873,
#   2731,
#   1035,
#   508,
#   1668,
#   1285,
#   1207,
#   572,
#   4109,
#   124,
#   4021,
#   1467,
#   2149,
#   815,
#   2758,
#   259,
#   4887,
#   4821,
#   2278],
#  [4109, 810, 2145, 1505, 2055, 2401, 4949, 4912, 1650, 239],
#  [2317, 1330, 1855, 1199, 368, 419, 3536, 4682, 3882, 137],
#  [1467, 1775, 2145, 3961, 1240, 4367, 2272],
#  [2659,
#   2528,
#   4267,
#   3310,
#   1467,
#   2906,
#   3310,
#   1937,
#   1587,
#   4412,
#   4532,
#   2145,
#   3310,
#   553,
#   3512,
#   4161,
#   4000,
#   1452,
#   2149,
#   1185,
#   3591,
#   841],
#  [3310,
#   1213,
#   1597,
#   4169,
#   2145,
#   3196,
#   2298,
#   752,
#   4912,
#   2126,
#   3310,
#   1105,
#   2401,
#   2022,
#   2298,
#   2556,
#   3883,
#   1213,
#   1597,
#   1213,
#   1597,
#   1213,
#   1597,
#   1213,
#   1597,
#   3555],
#  [3961,
#   846,
#   3766,
#   4031,
#   1506,
#   954,
#   216,
#   2149,
#   3108,
#   1493,
#   1396,
#   2099,
#   3613,
#   3953,
#   4412,
#   954,
#   4851,
#   343,
#   216,
#   2149,
#   728,
#   2736,
#   4039,
#   1575],
#  [4933, 4611, 4996, 3506, 2023, 2920, 2893, 4996, 4747, 1114, 921, 3514, 1442],
#  [2136,
#   2124,
#   4933,
#   4611,
#   3444,
#   4988,
#   2119,
#   1814,
#   4216,
#   6,
#   1505,
#   3549,
#   3895,
#   3132,
#   18,
#   1332,
#   2018,
#   1333,
#   3316],
#  [30,
#   4021,
#   1467,
#   72,
#   3436,
#   4021,
#   2050,
#   4082,
#   4081,
#   2149,
#   3222,
#   2145,
#   4413,
#   435,
#   939,
#   2050,
#   3335],
#  [4933, 2149, 3081, 1467, 4883, 4109, 4611, 525, 190, 4882, 1270, 1763],
#  [3310,
#   3310,
#   3310,
#   2995,
#   2236,
#   1037,
#   3021,
#   2659,
#   2099,
#   70,
#   481,
#   2540,
#   2018,
#   3100],
#  [1195,
#   2145,
#   4021,
#   719,
#   2392,
#   573,
#   2649,
#   1143,
#   3466,
#   3265,
#   4701,
#   4556,
#   2322,
#   1185,
#   734,
#   3499,
#   3337,
#   2896],
#  [2018,
#   2149,
#   1190,
#   875,
#   3222,
#   1257,
#   2321,
#   1163,
#   1730,
#   2965,
#   4034,
#   3356,
#   4184,
#   1485,
#   1068,
#   2987,
#   3840,
#   3356,
#   406],
#  [346,
#   312,
#   1855,
#   481,
#   1467,
#   1742,
#   1020,
#   4021,
#   3765,
#   2912,
#   1855,
#   1938,
#   1114,
#   2020],
#  [443, 4553, 594, 2099, 1033, 3916, 4087, 1455, 1427, 3716, 2145, 3463],
#  [2558,
#   3814,
#   3196,
#   34,
#   4861,
#   2145,
#   2149,
#   1029,
#   1638,
#   2867,
#   250,
#   1638,
#   2879,
#   3953,
#   4611,
#   2906,
#   2112,
#   4921],
#  [1862, 98, 4848, 4848, 3428, 2629, 2105],
#  [2699, 3872, 4007, 3119, 343, 538, 3310, 3310, 3310],
#  [1076, 3466, 1114, 4556, 3483, 2401, 4556, 3436, 2149, 4100, 216, 823, 1915],
#  [4887, 4267, 3436, 3196, 407, 3903, 4820, 2488],
#  [4454, 995, 2124, 3436, 346, 4538, 4087, 4538, 4087],
#  [2659,
#   1874,
#   1855,
#   175,
#   216,
#   2023,
#   647,
#   3466,
#   1037,
#   3961,
#   1037,
#   3310,
#   1240,
#   3466,
#   2652,
#   4109,
#   656,
#   837,
#   2208,
#   2061],
#  [3310, 3134, 319, 1668, 435, 2862, 4777, 1668, 435, 4777, 3291, 4632],
#  [3310,
#   3310,
#   4611,
#   1676,
#   4253,
#   4218,
#   3310,
#   4476,
#   4087,
#   4287,
#   3,
#   1084,
#   2906,
#   4611,
#   612],
#  [3764,
#   2145,
#   2008,
#   2149,
#   4576,
#   2156,
#   2099,
#   3716,
#   608,
#   1505,
#   631,
#   2149,
#   1981,
#   2145,
#   4253,
#   490,
#   690,
#   4267,
#   3132,
#   2149,
#   1849,
#   3521],
#  [4242, 4927, 2893, 2145, 4229, 447, 2214, 2136],
#  [4556,
#   3163,
#   4537,
#   4021,
#   2651,
#   2149,
#   1565,
#   2133,
#   1467,
#   3885,
#   4259,
#   728,
#   4081,
#   175,
#   2149,
#   1565,
#   2133,
#   1467,
#   3885,
#   4418,
#   175],
#  [3310,
#   3008,
#   689,
#   3437,
#   4021,
#   1467,
#   2659,
#   3352,
#   122,
#   579,
#   3201,
#   2145,
#   2238,
#   2149,
#   712,
#   2401,
#   1333,
#   3670,
#   4869,
#   1076],
#  [3310, 2124, 3436, 1730, 3310, 1],
#  [3310, 793, 3764, 3310, 481, 283],
#  [1742,
#   1467,
#   1190,
#   3764,
#   4679,
#   2511,
#   343,
#   4575,
#   636,
#   762,
#   330,
#   2504,
#   1931,
#   2255,
#   4672],
#  [879,
#   2524,
#   1323,
#   2119,
#   346,
#   3154,
#   3132,
#   2149,
#   2961,
#   2145,
#   4757,
#   3763,
#   1506,
#   3904,
#   2913,
#   4561,
#   2761],
#  [4804, 4994, 4251, 508, 2428, 4994, 4251, 508, 2428, 1041, 4100, 1693, 1931],
#  [3540,
#   3310,
#   3874,
#   2145,
#   1505,
#   4361,
#   4743,
#   1598,
#   2401,
#   4743,
#   1332,
#   2870,
#   2996,
#   2222],
#  [3399,
#   2119,
#   3242,
#   4736,
#   3418,
#   2426,
#   2099,
#   2125,
#   1899,
#   2145,
#   4933,
#   3466,
#   3182,
#   1443],
#  [3310,
#   769,
#   3310,
#   4927,
#   15,
#   4393,
#   579,
#   3310,
#   4081,
#   2452,
#   4253,
#   3885,
#   3164,
#   3640,
#   2562,
#   3310],
#  [3346,
#   4173,
#   3196,
#   2112,
#   694,
#   4267,
#   2145,
#   2149,
#   1232,
#   2995,
#   3197,
#   2867,
#   1029,
#   579],
#  [3307,
#   1467,
#   3885,
#   2119,
#   4477,
#   2145,
#   2572,
#   2906,
#   572,
#   2119,
#   524,
#   3132,
#   2960,
#   3469,
#   3359,
#   1831,
#   3307,
#   1291,
#   3054],
#  [1626, 2850, 2145, 1036, 883, 459, 3774, 3766, 4772],
#  [481, 3466, 2652, 4897, 3, 931, 4803, 1944, 1537, 61, 2918, 3281],
#  [3753, 4898, 2198, 333, 3753, 12, 1114, 1864, 1321],
#  [885,
#   1397,
#   1531,
#   2145,
#   1007,
#   2149,
#   1881,
#   2835,
#   2428,
#   3903,
#   2692,
#   566,
#   2766,
#   3310,
#   3310],
#  [3493, 4918, 274, 2623, 1855, 3809, 1221, 4837, 677, 4795, 3847],
#  [4853,
#   91,
#   2393,
#   2124,
#   553,
#   4556,
#   4972,
#   3563,
#   2099,
#   2128,
#   2601,
#   4611,
#   2771,
#   4548,
#   3498,
#   1114,
#   3968,
#   276,
#   3310],
#  [1937,
#   481,
#   435,
#   3753,
#   4877,
#   728,
#   4021,
#   3418,
#   2050,
#   2145,
#   2210,
#   1332,
#   4493,
#   2119,
#   4779,
#   2145,
#   2149,
#   3307,
#   3903,
#   2169,
#   577,
#   4081,
#   1190,
#   572,
#   1638],
#  [3466, 2652, 4827, 4081, 243, 4827, 504],
#  [4100, 2145, 2854, 2401, 3196, 2624, 693, 947, 305, 4343, 3307, 1114, 2379],
#  [2663, 1812, 2894, 1114, 3307, 1860, 2333, 3201, 546],
#  [4611, 346, 3961, 2119, 4579, 4983, 4579, 3968, 3583, 2997],
#  [2124,
#   1730,
#   2145,
#   1923,
#   4575,
#   3068,
#   4060,
#   3966,
#   4221,
#   4408,
#   1240,
#   1114,
#   1034],
#  [3501,
#   3442,
#   4991,
#   1485,
#   3923,
#   3021,
#   4611,
#   1443,
#   3163,
#   2099,
#   3356,
#   2067,
#   1452,
#   341,
#   2999,
#   2149,
#   1705,
#   1975,
#   4004],
#  [481,
#   2119,
#   4825,
#   3115,
#   4477,
#   1066,
#   1051,
#   883,
#   1376,
#   1855,
#   2149,
#   4160,
#   4818,
#   2401,
#   4021,
#   3731,
#   4380],
#  [4049,
#   4991,
#   343,
#   4611,
#   1037,
#   142,
#   883,
#   4991,
#   2995,
#   4611,
#   1037,
#   3433,
#   3716,
#   725,
#   4611,
#   4701,
#   3716,
#   2145,
#   3021,
#   1282],
#  [1832,
#   2004,
#   1526,
#   3461,
#   4978,
#   4804,
#   2004,
#   1526,
#   3461,
#   4978,
#   2149,
#   2004,
#   1526,
#   2025,
#   216,
#   2994,
#   3610,
#   2940],
#  [3310, 3310, 4983, 2945, 4701, 1274, 1790, 1170],
#  [3196,
#   2112,
#   1467,
#   2401,
#   1029,
#   3,
#   931,
#   3466,
#   1491,
#   4491,
#   1021,
#   3084,
#   1505,
#   2624,
#   283,
#   3753],
#  [2589, 2001, 1049, 2016, 2458, 2061, 3073, 4590, 4000, 2679],
#  [3716, 151, 4537, 2149, 4665, 1330, 2401, 376, 577, 1467, 4383],
#  [3310, 2099, 2995, 4611, 4087, 1594, 2995, 1049, 343],
#  [3466, 2652, 3887, 3466, 2652, 504, 2059],
#  [3466, 2652, 4827, 4081, 3078, 4827, 504],
#  [3310, 3310, 3310, 4021, 4368, 1491, 553, 508, 2252, 4087],
#  [3310, 525, 648, 4081, 851],
#  [3134, 3911, 2333, 1076, 3633, 92, 1201, 1118, 2844, 3940],
#  [4864, 4460, 123, 641, 3041, 2720, 2149, 3857, 1829, 3100, 2947, 1034],
#  [4021,
#   1443,
#   3934,
#   2149,
#   3039,
#   4927,
#   4109,
#   4804,
#   2659,
#   694,
#   2145,
#   3222,
#   2133,
#   1467,
#   1481,
#   2995,
#   2133,
#   1177,
#   4611,
#   2790,
#   2995,
#   660,
#   3778],
#  [3310,
#   3483,
#   4267,
#   2149,
#   3288,
#   394,
#   3466,
#   2610,
#   4814,
#   3614,
#   3466,
#   2610,
#   4814,
#   3466,
#   2610,
#   4814,
#   3466,
#   811],
#  [4017,
#   123,
#   2145,
#   3436,
#   2149,
#   2556,
#   1440,
#   4267,
#   3613,
#   2099,
#   4017,
#   343,
#   4109,
#   188,
#   4081,
#   3197,
#   2867,
#   3758,
#   883],
#  [2969, 2330, 1443, 61, 3774, 4772, 3766],
#  [1565, 3953, 2125, 3716, 3436, 3310],
#  [1615, 4134, 1783, 2722, 4041, 1783, 1014, 4855],
#  [3310, 4978, 1018, 2906, 883, 240, 2606, 854, 692],
#  [3310,
#   1037,
#   3961,
#   577,
#   4081,
#   2119,
#   3440,
#   3466,
#   1037,
#   2693,
#   3716,
#   4109,
#   3466,
#   1037,
#   821,
#   3436,
#   2149,
#   2974,
#   1506,
#   524,
#   2995,
#   3798,
#   901,
#   4216,
#   3466,
#   2128],
#  [1855, 2149, 734, 3826, 2936, 1265, 4097, 508, 2711],
#  [1076, 3466, 1114, 4556, 3483, 2401, 4556, 3436, 2149, 4100, 216, 823, 1915],
#  [346,
#   123,
#   4057,
#   1862,
#   3860,
#   2906,
#   2870,
#   121,
#   3903,
#   3712,
#   4875,
#   1084,
#   2906,
#   2149,
#   624,
#   4032,
#   2149,
#   3310,
#   1738,
#   3903,
#   631,
#   1855,
#   2145,
#   3310,
#   2447],
#  [418,
#   4562,
#   2119,
#   2831,
#   2756,
#   1303,
#   271,
#   1506,
#   3310,
#   2696,
#   3669,
#   2061,
#   4947,
#   4239,
#   4196],
#  [3466,
#   4701,
#   2145,
#   2240,
#   4611,
#   1114,
#   4537,
#   391,
#   1675,
#   3638,
#   3716,
#   1207,
#   3074,
#   1291,
#   1114,
#   4572,
#   2497,
#   1938,
#   967,
#   1586,
#   1117],
#  [3466, 2652, 4827, 4081, 931, 4827, 504],
#  [3364,
#   2659,
#   3638,
#   2192,
#   1783,
#   4136,
#   4121,
#   3310,
#   525,
#   648,
#   4081,
#   1842,
#   2145,
#   2169,
#   2145,
#   4255,
#   1893,
#   161],
#  [3310, 259, 989, 33, 931, 4100, 4081, 3310, 216, 2119, 2241, 2849, 2192],
#  [2715,
#   2119,
#   890,
#   4034,
#   690,
#   1332,
#   3474,
#   4679,
#   2945,
#   4017,
#   1975,
#   1185,
#   987,
#   2431,
#   4256,
#   2128,
#   1578,
#   4409,
#   123],
#  [4611,
#   1675,
#   4996,
#   2133,
#   346,
#   1505,
#   2119,
#   3846,
#   1855,
#   4611,
#   890,
#   397,
#   3288,
#   2959,
#   1114,
#   3846,
#   4118,
#   589,
#   41],
#  [3196, 2126, 2659, 2547, 652, 4560],
#  [769, 2192, 3944, 558, 1045, 3132, 1012, 4593, 890, 1673],
#  [1537,
#   3209,
#   608,
#   2870,
#   190,
#   553,
#   2870,
#   2156,
#   481,
#   4675,
#   2145,
#   3961,
#   3961,
#   559],
#  [3466, 2652, 680, 3466, 2652, 504, 2059],
#  [2145,
#   2149,
#   3507,
#   2133,
#   3132,
#   394,
#   1506,
#   2149,
#   713,
#   3132,
#   2149,
#   2283,
#   3466,
#   3163,
#   391,
#   3755,
#   4611,
#   1310,
#   1505,
#   2149,
#   3,
#   2145,
#   1923,
#   3590],
#  [4983,
#   4611,
#   4489,
#   2297,
#   2119,
#   2083,
#   4081,
#   2119,
#   1857,
#   4216,
#   1171,
#   2119,
#   1857,
#   2995,
#   3885,
#   4216,
#   2124,
#   2119,
#   3668,
#   4837,
#   2145,
#   3021,
#   1761,
#   1310,
#   3624,
#   2208,
#   2145,
#   3412,
#   3716],
#  [4933, 883, 2351, 2119, 346, 3765, 2995, 3716, 4368, 4827, 810, 1620, 1407],
#  [4933,
#   4611,
#   1505,
#   2119,
#   346,
#   2112,
#   2995,
#   1856,
#   1742,
#   4611,
#   1066,
#   885,
#   2145,
#   3961,
#   2149,
#   4253,
#   2133,
#   1178,
#   3498,
#   1102],
#  [2149, 2317, 254, 1765, 2758, 4702, 2458, 1852, 899, 752, 2172, 810, 1864],
#  [4087,
#   4611,
#   2583,
#   4081,
#   3242,
#   1915,
#   3971,
#   769,
#   4087,
#   1104,
#   3310,
#   3310,
#   3310,
#   3310],
#  [525,
#   648,
#   4081,
#   4399,
#   2583,
#   2145,
#   2210,
#   3310,
#   2995,
#   3310,
#   4100,
#   2145,
#   217,
#   2489],
#  [15, 3330, 3196, 3486, 4428, 1050],
#  [4081,
#   3260,
#   801,
#   4611,
#   4087,
#   4611,
#   1817,
#   32,
#   3285,
#   3132,
#   3307,
#   2995,
#   4611,
#   4709,
#   3021,
#   2149,
#   3994,
#   174],
#  [681, 675, 2210, 4611, 3197, 216, 4550],
#  [2562, 3132, 2149, 123, 656, 4081, 1905, 3595, 152, 4777, 2756, 2562],
#  [4673, 854, 840, 4003, 2733, 3766, 4413],
#  [3134, 312, 600, 2401, 3720, 394, 538, 3974],
#  [3310,
#   1082,
#   4556,
#   3961,
#   756,
#   2145,
#   3808,
#   435,
#   371,
#   1947,
#   1289,
#   2945,
#   3281,
#   2079,
#   2995,
#   608,
#   1505,
#   2145,
#   3969],
#  [2870, 4087, 3134, 3999, 442, 3209, 1714, 1332, 78, 3009, 90],
#  [3310,
#   3310,
#   3310,
#   2609,
#   4611,
#   793,
#   188,
#   4081,
#   4021,
#   818,
#   1037,
#   756,
#   3716,
#   1864,
#   3878,
#   4973],
#  [2703, 4748, 712],
#  [2110, 2987, 2192, 3197, 2133, 1467, 1104],
#  [3134, 579, 2731, 4607, 3335, 4906, 1373],
#  [3310,
#   3134,
#   2906,
#   1902,
#   4827,
#   2428,
#   3,
#   4604,
#   2114,
#   2145,
#   4087,
#   3132,
#   3604,
#   238,
#   3355],
#  [2870, 3281, 3352, 1192, 3132, 435, 4239, 4118, 4040, 4814],
#  [1419, 1695, 472, 3137, 4498, 3310, 3310, 3310],
#  [190, 3523, 2196, 843, 3026, 3026, 2314, 1928, 2235, 2387, 2972, 603, 2106],
#  [805,
#   4991,
#   343,
#   4611,
#   1037,
#   142,
#   883,
#   4991,
#   2995,
#   4611,
#   1037,
#   3433,
#   3716,
#   725,
#   4611,
#   4701,
#   3716,
#   2145,
#   3021,
#   4933],
#  [4927, 4109, 2583, 4081, 4795, 468, 3129, 4208, 365],
#  [216, 45, 3132, 3196, 3661, 2881, 1066, 251, 1416, 1597, 4155, 3251],
#  [3310,
#   3310,
#   1855,
#   1257,
#   1542,
#   2149,
#   4146,
#   1247,
#   1730,
#   2145,
#   2210,
#   1467,
#   1519,
#   4109,
#   3184,
#   3687,
#   70,
#   2945,
#   338,
#   3716,
#   216,
#   2119,
#   110,
#   862],
#  [3533, 2511, 2124, 636, 2119, 3999],
#  [291, 3903, 2541, 4823, 3132, 2699, 1539, 587, 1894],
#  [2731, 2119, 3661, 123, 854, 1379, 4462, 2719, 2216, 2041, 1639, 645],
#  [3308,
#   3745,
#   4370,
#   4239,
#   4440,
#   2623,
#   1902,
#   4298,
#   4767,
#   3903,
#   1597,
#   13,
#   2906,
#   233,
#   90,
#   1132,
#   3079],
#  [3109, 1790, 4611, 2987, 3840, 4611, 4996, 2671, 2422, 2897],
#  [3310,
#   4021,
#   3911,
#   1243,
#   4081,
#   709,
#   3132,
#   1253,
#   2149,
#   4477,
#   2401,
#   2149,
#   2543,
#   1696,
#   724,
#   4831,
#   1034],
#  [4315,
#   3106,
#   4213,
#   1333,
#   2564,
#   490,
#   3941,
#   572,
#   2598,
#   2149,
#   3994,
#   1594,
#   977,
#   3614,
#   3328],
#  [2133, 2128, 1948, 2149, 2730, 4139, 614, 2192, 605],
#  [1240, 2321, 3961, 4573, 579, 2149, 4100, 3310, 2674, 1084, 1280, 4855],
#  [1076, 3466, 1114, 4556, 3483, 2401, 4556, 3436, 2149, 4100, 216, 823, 1915],
#  [3310,
#   2750,
#   4034,
#   3937,
#   1775,
#   216,
#   1114,
#   2401,
#   4021,
#   1485,
#   1054,
#   1485,
#   253,
#   251,
#   3937],
#  [553,
#   4114,
#   4832,
#   3369,
#   579,
#   553,
#   4114,
#   4070,
#   2995,
#   2125,
#   1784,
#   2051,
#   708,
#   1329],
#  [1095, 1467, 1730, 2149, 3765],
#  [4969,
#   4786,
#   3549,
#   2987,
#   1730,
#   3197,
#   1976,
#   70,
#   553,
#   188,
#   2945,
#   4999,
#   2906,
#   2149,
#   1045,
#   3132,
#   2149,
#   994],
#  [4935, 1467, 1385, 3985, 4711, 1120, 3310, 3310, 3310],
#  [596,
#   2145,
#   3436,
#   2149,
#   3197,
#   2133,
#   338,
#   2881,
#   4267,
#   3613,
#   2870,
#   1114,
#   4611,
#   2522],
#  [1443,
#   1668,
#   2145,
#   3196,
#   2362,
#   1114,
#   4611,
#   1864,
#   2564,
#   4611,
#   3134,
#   1617,
#   346,
#   2426,
#   2522,
#   3310],
#  [4737, 3436, 435, 1900, 2731, 254, 3242, 2145, 914],
#  [2955, 1118, 1114, 4611, 3197, 1948, 4969, 761, 2736, 3100],
#  [2149, 3495, 1948, 2583, 2145, 3961, 2581, 447, 2124, 1855, 12, 2611],
#  [1852,
#   1467,
#   2149,
#   123,
#   2145,
#   4673,
#   2149,
#   3488,
#   4507,
#   2827,
#   2995,
#   1889,
#   2145,
#   1240,
#   2119,
#   504,
#   3204,
#   4738,
#   1157],
#  [3310,
#   1389,
#   4860,
#   1551,
#   4109,
#   1104,
#   501,
#   3122,
#   1505,
#   2119,
#   793,
#   3134,
#   20,
#   106,
#   3114],
#  [3418, 123, 2906, 61, 4795, 4081, 175, 4825, 3946, 1506, 494, 2581, 3915],
#  [3310, 1612, 1758, 2859, 1758, 3911, 4109, 1612, 3283, 2651, 2976],
#  [3196, 3134, 3999, 2859, 1852, 1223],
#  [1675,
#   4412,
#   2987,
#   778,
#   3466,
#   1505,
#   4605,
#   1593,
#   3132,
#   481,
#   4927,
#   3514,
#   3,
#   931,
#   2581,
#   213,
#   3351],
#  [3310, 1505, 2119, 3671, 494, 947, 4003, 494, 293],
#  [3466,
#   2659,
#   2898,
#   178,
#   2402,
#   614,
#   4312,
#   2061,
#   3872,
#   1855,
#   93,
#   2659,
#   3330,
#   3310,
#   742,
#   2077,
#   1298,
#   2580],
#  [385, 3471, 3134, 2363, 4611, 2128, 1948, 2119, 1960, 4439],
#  [1979, 2995, 2022, 2126, 3201, 902, 137, 4376, 309],
#  [4983,
#   4611,
#   1505,
#   1675,
#   3281,
#   2119,
#   1597,
#   4253,
#   2145,
#   136,
#   4379,
#   4611,
#   1310,
#   1948,
#   2119,
#   446,
#   2894,
#   1855,
#   2149,
#   3281,
#   565],
#  [4747,
#   1467,
#   2149,
#   2283,
#   2880,
#   4611,
#   3084,
#   1817,
#   883,
#   4947,
#   2659,
#   4081,
#   4742,
#   883,
#   1280,
#   1029],
#  [3466,
#   4785,
#   1842,
#   2156,
#   2099,
#   3109,
#   1452,
#   423,
#   2145,
#   3135,
#   2149,
#   896,
#   216,
#   572,
#   4056,
#   1185,
#   1424,
#   1506,
#   4299,
#   4267],
#  [346, 3437, 1389, 2401, 3310, 2416, 2145, 3225, 4081, 3310, 1497, 2731],
#  [36, 4000, 579, 3310, 216, 2149, 4651, 579, 3310],
#  [4556,
#   4361,
#   72,
#   4031,
#   3466,
#   3618,
#   4412,
#   1583,
#   762,
#   4853,
#   3903,
#   424,
#   3716,
#   1037,
#   1915,
#   2119,
#   1267,
#   3132,
#   3037,
#   823,
#   4098,
#   4556,
#   2149,
#   4912],
#  [3307,
#   3088,
#   3201,
#   3307,
#   1467,
#   30,
#   2995,
#   1801,
#   4556,
#   3498,
#   3201,
#   3418,
#   1864,
#   2995,
#   1675,
#   1801,
#   3347,
#   396],
#  [77,
#   1618,
#   1143,
#   3641,
#   3971,
#   2113,
#   2633,
#   3725,
#   235,
#   3799,
#   3642,
#   733,
#   44,
#   2198,
#   2402],
#  [3310,
#   3716,
#   1467,
#   3885,
#   1332,
#   2133,
#   4087,
#   4827,
#   3716,
#   1467,
#   4827,
#   1332,
#   2133,
#   4087,
#   3134,
#   1451],
#  [3466, 2652, 1252, 3466, 2652, 504, 2059],
#  [3466,
#   1505,
#   2230,
#   1084,
#   4246,
#   3466,
#   1505,
#   214,
#   3134,
#   4246,
#   3903,
#   3493,
#   2870,
#   4372,
#   2119,
#   994,
#   4795,
#   3310,
#   3310,
#   107],
#  [1668, 1429, 1506, 3196, 3299, 2995, 3196, 853, 3837, 4950, 1668, 3560],
#  [3310,
#   2353,
#   216,
#   51,
#   4738,
#   3132,
#   1136,
#   4216,
#   3310,
#   2125,
#   3716,
#   1452,
#   2145,
#   4436,
#   2145,
#   1241,
#   6,
#   1018,
#   1855,
#   3260,
#   4006,
#   2426,
#   1034],
#  [3310,
#   614,
#   3134,
#   4859,
#   2731,
#   2149,
#   793,
#   36,
#   3526,
#   2906,
#   2149,
#   3718,
#   2318,
#   264,
#   1060,
#   3310],
#  [481, 2119, 3450, 3253, 4081, 3477],
#  [3466, 2652, 4827, 4081, 3365, 4827, 504],
#  [346, 1565, 4034, 4409],
#  [3310, 3111, 614, 2689, 1235, 975, 4955, 1118, 4097, 4955, 3766, 1790, 4947],
#  [36,
#   647,
#   70,
#   1285,
#   931,
#   2124,
#   4665,
#   2192,
#   3197,
#   2149,
#   739,
#   3132,
#   2149,
#   1045,
#   3132,
#   3310,
#   3466,
#   2652,
#   3148,
#   2995,
#   3764,
#   2906,
#   2149,
#   3994,
#   4100,
#   349],
#  [2124, 2119, 3271, 1920, 3381, 1034],
#  [2845,
#   3442,
#   4991,
#   1485,
#   3923,
#   3021,
#   4611,
#   1443,
#   3163,
#   2099,
#   3356,
#   2067,
#   1452,
#   341,
#   2999,
#   2149,
#   1705,
#   1975,
#   4004,
#   1467],
#  [596, 2145, 3436, 435, 2149, 2556, 4017, 4267, 3613, 854],
#  [3466, 2659, 4701, 2145, 3961, 1467, 2099, 2651, 188, 2145, 200, 4081, 665],
#  [3310, 2583, 2995, 4082, 4581],
#  [4927, 3764, 3196, 1729, 3369, 2037, 2236, 1452, 2678, 693],
#  [3029, 1972, 1922, 1506, 3109, 2099, 4361, 72, 671],
#  [3959,
#   2208,
#   1408,
#   778,
#   2906,
#   3658,
#   2250,
#   1981,
#   1670,
#   1855,
#   2119,
#   2393,
#   3701,
#   2651],
#  [3310,
#   2169,
#   1855,
#   3310,
#   4611,
#   2128,
#   3021,
#   4001,
#   3840,
#   4021,
#   1903,
#   3696,
#   1619,
#   216,
#   3310,
#   1918,
#   555,
#   3607,
#   4742,
#   3588],
#  [2259,
#   175,
#   190,
#   175,
#   4927,
#   2659,
#   2119,
#   1937,
#   2079,
#   4803,
#   2054,
#   175,
#   4021,
#   4266,
#   1467,
#   3885,
#   2149,
#   4266,
#   3466,
#   1622,
#   4533,
#   4031,
#   3132,
#   3903,
#   2149,
#   566,
#   1090,
#   3549],
#  [3131, 3250, 4617, 2149, 2562, 2128, 2131, 1948, 3972],
#  [4927, 4109, 2995, 1110, 931, 2099, 1301],
#  [296,
#   2987,
#   1285,
#   2145,
#   1923,
#   70,
#   1612,
#   1613,
#   1964,
#   2440,
#   2145,
#   2210,
#   3310,
#   3466,
#   3413,
#   648,
#   2145,
#   2210,
#   3196,
#   3999,
#   1794,
#   213,
#   2841],
#  [4169, 343, 2122, 2122, 2122, 2122, 2122, 2122, 2122],
#  [3310, 2149, 953, 3132, 2149, 1405, 617, 3617, 539, 4836, 2751, 982, 3863],
#  [1616, 4021, 1467, 175, 3418, 1855, 3903, 1716],
#  [87,
#   3466,
#   3764,
#   2099,
#   4556,
#   4087,
#   2119,
#   2894,
#   897,
#   4109,
#   3466,
#   200,
#   4556,
#   2145,
#   3540,
#   3196,
#   2393,
#   41,
#   2124,
#   1918,
#   2018,
#   3196,
#   2894,
#   1855,
#   4027],
#  [3725, 2018, 3281, 4341, 2599, 2718, 4381, 3971, 2531, 1329, 1747],
#  [3310, 1772, 2156, 3466, 1114, 4611, 2145, 883, 2881, 3, 931, 1252, 2975],
#  [4458, 2133, 1084, 1084, 2272, 4803, 3638, 2387, 2214, 1677, 4992, 4447],
#  [87, 3720, 4611, 608, 4701, 2145, 3540, 4081, 2565, 2388, 1855, 2533, 652],
#  [3310,
#   3310,
#   3310,
#   3310,
#   3310,
#   1668,
#   2157,
#   1565,
#   1615,
#   4611,
#   2024,
#   2119,
#   1573,
#   3365],
#  [2358,
#   957,
#   3064,
#   1114,
#   1776,
#   2995,
#   3006,
#   1431,
#   3238,
#   3716,
#   343,
#   3617,
#   1467,
#   2222,
#   446,
#   2119,
#   4805,
#   4275,
#   4778,
#   4745,
#   2145,
#   2792],
#  [3540,
#   4267,
#   3196,
#   582,
#   3026,
#   4253,
#   2388,
#   3078,
#   2099,
#   1452,
#   1639,
#   579,
#   1695,
#   1491,
#   975,
#   4226],
#  [1076, 3466, 1114, 4556, 3483, 2401, 4556, 3436, 2149, 4100, 216, 823, 1915],
#  [3310,
#   4611,
#   1675,
#   1778,
#   175,
#   1730,
#   883,
#   2606,
#   1855,
#   2149,
#   117,
#   323,
#   1979,
#   3903,
#   1703,
#   2965,
#   2528,
#   4904],
#  [2775, 2890, 2888, 2053, 612, 2569, 1903, 4354],
#  [785,
#   1814,
#   2542,
#   4611,
#   2961,
#   2145,
#   3021,
#   2145,
#   1199,
#   2145,
#   2149,
#   1957,
#   2149,
#   2961,
#   2145,
#   2937,
#   2149,
#   1705,
#   4445],
#  [803,
#   2149,
#   3310,
#   4569,
#   1493,
#   3903,
#   931,
#   2591,
#   142,
#   1467,
#   4615,
#   3903,
#   4021,
#   1467,
#   931,
#   2149,
#   3310,
#   781,
#   2119,
#   781,
#   3132,
#   478,
#   3903,
#   3614,
#   2205],
#  [3466, 1114, 553, 3466, 2652, 4109, 471, 4081, 3196, 2739, 3617],
#  [4454, 995, 2124, 3436, 346, 4538, 4087, 4538, 4087],
#  [3310, 2124, 4343, 2119, 346, 3514, 4933, 4021, 3728, 1783, 3658, 2984, 4412],
#  [3540,
#   3716,
#   2806,
#   4658,
#   2835,
#   508,
#   4940,
#   3958,
#   4146,
#   2913,
#   1332,
#   3048,
#   1534,
#   4369],
#  [706, 216, 2023, 2192, 3209],
#  [3310, 2124, 3310, 2773, 854, 552, 1643, 3310, 3310, 3818],
#  [4590,
#   1467,
#   4267,
#   3134,
#   1537,
#   2328,
#   2558,
#   216,
#   2149,
#   4590,
#   123,
#   2011,
#   4590,
#   651],
#  [2653,
#   4732,
#   1971,
#   2145,
#   3961,
#   3622,
#   2401,
#   2149,
#   2758,
#   3132,
#   2149,
#   4721,
#   4081,
#   3109,
#   3310,
#   2125,
#   2318],
#  [1595, 4958, 1484],
#  [3134,
#   989,
#   123,
#   3109,
#   2145,
#   3196,
#   2881,
#   2995,
#   3436,
#   3132,
#   2149,
#   2208,
#   4267,
#   3613,
#   4017,
#   123,
#   3109],
#  [3310,
#   4847,
#   1467,
#   216,
#   4927,
#   2222,
#   3528,
#   3753,
#   4868,
#   1049,
#   4531,
#   1114,
#   1915,
#   4865],
#  [581, 2825, 3132, 2149, 994, 4110, 1292, 3109, 192, 2822, 1494, 1151],
#  [3310, 4769, 3310, 181, 3911, 3307, 1114, 4443, 546],
#  [3196, 3999, 1794, 3953, 2119, 4758, 2806, 3132, 698, 3840, 175, 897],
#  [4737,
#   4021,
#   3428,
#   2119,
#   1668,
#   1038,
#   2640,
#   3310,
#   1467,
#   2149,
#   1875,
#   4567,
#   3132,
#   2799],
#  [3466, 2652, 4827, 4081, 395, 2329, 4827, 504],
#  [3436,
#   781,
#   2319,
#   2145,
#   4447,
#   2119,
#   3958,
#   922,
#   1000,
#   2119,
#   1584,
#   2870,
#   1310,
#   4701,
#   2149,
#   2283,
#   2145,
#   4996],
#  [3310,
#   3693,
#   2170,
#   539,
#   508,
#   2145,
#   1051,
#   883,
#   4989,
#   3922,
#   2995,
#   2747,
#   1531,
#   4390,
#   1034],
#  [4611, 346, 3961, 2119, 4579, 4983, 4579, 3968, 3583, 2997],
#  [3310, 1784, 2640, 2792, 4537, 2099, 3310, 3487],
#  [1066, 3961, 1899],
#  [3310,
#   854,
#   3466,
#   3281,
#   2119,
#   4963,
#   1513,
#   313,
#   2870,
#   821,
#   4081,
#   1114,
#   3885,
#   2875,
#   1332,
#   420,
#   635],
#  [4969,
#   3197,
#   2651,
#   24,
#   1730,
#   3197,
#   3887,
#   3492,
#   2145,
#   3961,
#   50,
#   2401,
#   3197,
#   2623],
#  [3466,
#   3614,
#   4537,
#   2836,
#   3132,
#   3196,
#   4239,
#   3466,
#   1452,
#   1443,
#   345,
#   3524,
#   2119,
#   4872,
#   142,
#   4473,
#   4779,
#   1335,
#   3722,
#   1310,
#   4017,
#   2119,
#   3281,
#   1730,
#   175,
#   748,
#   3466,
#   2547,
#   1790],
#  [1948, 343, 1948, 1948, 3758, 508, 854, 2393, 1859, 2393, 508],
#  [4912, 1812, 1047, 4081, 4772, 3774, 3766, 1467, 3740],
#  [3477,
#   1253,
#   2803,
#   2804,
#   4226,
#   2710,
#   3282,
#   1730,
#   151,
#   3121,
#   1282,
#   3124,
#   3264,
#   2797],
#  [4087, 4611, 2119, 3310, 1110, 4021, 4709, 4673, 4611],
#  [508, 2018, 278, 2018, 2119, 2310, 4081, 4772, 3774, 3766, 1467],
#  [553, 2128, 121, 4673, 2119, 4239, 4207, 1301],
#  [2689, 1502, 4809, 2638, 1783, 2149, 4758, 1258],
#  [1505, 2119, 1482, 3765, 752, 2938, 237, 2375],
#  [4933,
#   4927,
#   3514,
#   4225,
#   2995,
#   3466,
#   1136,
#   4575,
#   2995,
#   2210,
#   2119,
#   354,
#   2265,
#   2145,
#   3961,
#   3134,
#   2272,
#   3466,
#   1114,
#   4611,
#   379],
#  [1084, 2145, 2149, 123, 2185, 4081, 435, 1394],
#  [2363,
#   3,
#   931,
#   2023,
#   3471,
#   2701,
#   972,
#   3903,
#   2330,
#   1506,
#   3471,
#   988,
#   3310,
#   2012,
#   1902,
#   2387,
#   4873,
#   3255],
#  [372,
#   3339,
#   2994,
#   4810,
#   3763,
#   3639,
#   49,
#   1337,
#   1360,
#   3834,
#   1915,
#   2149,
#   4898,
#   3132,
#   555,
#   2323,
#   1467,
#   2651,
#   3891,
#   4609,
#   4825],
#  [3196, 494, 1467, 4109, 341, 3374, 2149, 3942, 777, 690, 341, 3798],
#  [4430, 4239, 1565, 1880, 4165, 2995, 1385, 216, 1215, 2569, 1467, 931, 2935],
#  [3310,
#   2149,
#   1132,
#   2640,
#   1587,
#   4081,
#   4008,
#   1938,
#   1876,
#   216,
#   2099,
#   2475,
#   4611,
#   4087,
#   103,
#   3132,
#   3141,
#   827,
#   844,
#   1627,
#   4552],
#  [346, 2426, 1203, 2758, 2197],
#  [3021,
#   481,
#   4611,
#   1114,
#   2145,
#   3021,
#   1256,
#   4081,
#   2149,
#   1114,
#   3132,
#   3716,
#   1114,
#   2333,
#   61,
#   2660],
#  [4985, 2401, 583, 1268, 4343, 1275, 3747, 1413, 4744, 3310],
#  [3310,
#   3196,
#   1513,
#   4297,
#   3624,
#   4996,
#   3466,
#   1452,
#   803,
#   2022,
#   776,
#   2401,
#   2149,
#   3022,
#   4977,
#   1452,
#   4082,
#   4081,
#   1842,
#   2651,
#   2156,
#   2149,
#   3591,
#   1589],
#  [2959, 4267, 2959, 1084, 33, 1751, 4287, 2959, 4428, 4702, 1809, 889],
#  [4524, 3466, 1452, 921, 1923, 2210, 3409, 2401, 2624],
#  [3310,
#   4952,
#   175,
#   121,
#   538,
#   2061,
#   2401,
#   1291,
#   1114,
#   1565,
#   2326,
#   3765,
#   1553,
#   2195,
#   276,
#   4591,
#   2185],
#  [1286,
#   2004,
#   1526,
#   3461,
#   4978,
#   4804,
#   2004,
#   1526,
#   3461,
#   4978,
#   2149,
#   2004,
#   1526,
#   2025,
#   216,
#   2994,
#   1330],
#  [193, 193, 3766, 1701],
#  [2222, 3613, 2128, 2870, 4929, 216, 15, 2091, 1938, 2027, 2912, 4447],
#  [1612, 4082, 4081, 2119, 2473, 2426, 2149, 1816, 4183],
#  [3310, 572, 2124, 883, 110, 4611, 1505, 2145, 4972, 3716, 2145, 2979],
#  [3310, 4021, 994, 1247, 2416, 1775, 2040, 572, 2124, 4299, 4001, 4593, 384],
#  [3310,
#   1864,
#   3310,
#   4008,
#   3911,
#   3109,
#   4652,
#   2651,
#   3971,
#   2236,
#   3109,
#   1467,
#   216,
#   1756,
#   1240,
#   1915,
#   1522,
#   762,
#   1110,
#   3197,
#   3196,
#   2002,
#   142,
#   3588],
#  [1310, 1697, 168],
#  [193, 3485, 2995, 2473, 175, 752, 2721, 3204, 1353, 4001, 4316, 1586, 1034],
#  [1812, 4081, 4772, 3893, 3961, 3766, 4524, 3740],
#  [581,
#   2820,
#   3923,
#   817,
#   2145,
#   1492,
#   1503,
#   2697,
#   160,
#   3755,
#   3651,
#   4081,
#   2739,
#   3706,
#   192,
#   2822,
#   1494,
#   1151],
#  [2894, 216, 1862, 778, 1467, 1534, 915],
#  [36, 1668, 2145, 435, 712, 1854, 2000, 2387, 4099, 2458, 1912, 3310],
#  [3310, 2447, 1232, 2308, 1470, 2455, 216, 2980, 2029, 4124, 4146],
#  [3310,
#   3294,
#   1675,
#   3964,
#   175,
#   2099,
#   3928,
#   1505,
#   2149,
#   3,
#   2145,
#   1526,
#   614,
#   2191,
#   322],
#  [2401, 3196, 752, 2539, 1467, 2119, 2899, 2145, 4996, 2845, 1727, 1783, 417],
#  [854,
#   4939,
#   3123,
#   3165,
#   781,
#   2906,
#   2364,
#   3310,
#   3903,
#   3310,
#   4198,
#   4121,
#   2145,
#   2210,
#   3148,
#   2272],
#  [875, 368, 1510],
#  [3310, 3466, 525, 648, 2145, 1923, 2210, 3872, 4855, 4900, 3872],
#  [3882, 1580, 4239, 1534, 3310, 2832],
#  [2906, 3310, 4081, 4662, 3600, 2401, 3186, 279, 2636, 4709, 3961, 793, 2638],
#  [3196, 3692, 1305, 631, 4109, 4927, 411, 1181],
#  [1505,
#   3196,
#   897,
#   3210,
#   2965,
#   4804,
#   2906,
#   175,
#   2837,
#   72,
#   2122,
#   2122,
#   2122,
#   897,
#   2126,
#   2100,
#   1114],
#  [3310,
#   4933,
#   1247,
#   4393,
#   579,
#   2119,
#   2616,
#   4216,
#   4611,
#   3560,
#   2145,
#   3676,
#   3903,
#   2047,
#   3356,
#   4802,
#   1217,
#   3750],
#  [989,
#   123,
#   2145,
#   3436,
#   2149,
#   1440,
#   577,
#   2995,
#   2149,
#   1215,
#   2099,
#   4087,
#   216,
#   990],
#  [3688, 3310, 4110, 4410, 3310],
#  [553,
#   3748,
#   575,
#   4087,
#   614,
#   4681,
#   12,
#   2149,
#   4124,
#   3213,
#   4537,
#   4367,
#   1855,
#   3310,
#   4547,
#   2318],
#  [4972, 2149, 2282, 3132, 883, 2208, 2145, 1036, 883, 3339, 3774, 3766, 1467],
#  [3928, 4927, 2119, 2587, 1985, 2587, 1933, 1714],
#  [3310,
#   2870,
#   1310,
#   2537,
#   4216,
#   885,
#   3134,
#   885,
#   4216,
#   2870,
#   2537,
#   4050,
#   4190,
#   4251],
#  [1505,
#   2119,
#   3134,
#   4958,
#   1742,
#   3466,
#   3163,
#   854,
#   1467,
#   2893,
#   2145,
#   3961,
#   2119,
#   346,
#   123,
#   2955,
#   291,
#   4958],
#  [2128,
#   2870,
#   4745,
#   1730,
#   2149,
#   2850,
#   216,
#   922,
#   238,
#   633,
#   72,
#   2995,
#   553,
#   1735,
#   1675,
#   2230,
#   122],
#  [2353, 216, 2149, 3573, 3472, 1336, 883, 4031, 2319],
#  [3466,
#   1505,
#   2145,
#   2049,
#   1758,
#   2986,
#   3466,
#   1734,
#   3196,
#   4862,
#   1593,
#   4081,
#   4732,
#   4021,
#   1132],
#  [2063, 2401, 1513, 1297, 2959, 1513, 1134],
#  [2133, 4256, 1467, 4259, 1855, 803, 3310, 4795, 1104, 3557],
#  [4243,
#   1244,
#   123,
#   357,
#   2478,
#   4109,
#   651,
#   4935,
#   1467,
#   806,
#   2145,
#   3301,
#   4410,
#   3466,
#   2758,
#   2547,
#   3310,
#   3310,
#   3310,
#   4858],
#  [111, 3109, 2426, 3248, 4673, 3197, 245, 4081, 3581, 3370, 4413, 854],
#  [3310, 4216, 3466, 2652, 3134, 4191, 3307, 1050],
#  [1333, 2381, 2077, 4081, 4114, 1957, 3628, 3628, 4008, 4384, 2655],
#  [3310,
#   2079,
#   1301,
#   2619,
#   2995,
#   2119,
#   3999,
#   4796,
#   4667,
#   4807,
#   3903,
#   1868,
#   2021,
#   3895,
#   3310,
#   3310,
#   3310],
#  [4491, 648, 4081, 2243, 4021, 2050, 1352, 4824],
#  [793,
#   2145,
#   61,
#   2401,
#   4843,
#   2528,
#   2840,
#   3351,
#   139,
#   3196,
#   2126,
#   1610,
#   1767,
#   1034],
#  [4034, 2149, 3585, 2360, 724, 3472, 421, 4081, 2100, 2736, 3385, 4379],
#  [257, 3978, 2208, 4590, 1114, 2785, 4170, 2061, 4239, 1191, 2766, 3399, 384],
#  [1784,
#   4537,
#   2119,
#   785,
#   873,
#   4871,
#   3490,
#   2904,
#   2145,
#   2653,
#   4611,
#   343,
#   4734,
#   2012,
#   1867,
#   1226,
#   4630],
#  [1806,
#   272,
#   4252,
#   2995,
#   2043,
#   1065,
#   3742,
#   1243,
#   4927,
#   3493,
#   2393,
#   1506,
#   3137,
#   2995,
#   1119,
#   2080,
#   2939,
#   3134,
#   1806,
#   1477],
#  [2023, 1862, 4752, 4087, 343, 749, 3976, 2065, 618, 3248, 738, 3490],
#  [3466, 2652, 4827, 4081, 3196, 443, 4827, 504],
#  [1613, 2426, 216, 2401, 3978, 2208, 3903, 4065, 580, 1613],
#  [3310,
#   1470,
#   1435,
#   2840,
#   216,
#   3439,
#   1703,
#   4426,
#   1979,
#   3132,
#   435,
#   1696,
#   724,
#   472,
#   3092],
#  [3310, 2762, 824, 791, 111, 4537, 2923, 4035, 4751, 2195, 98, 3910],
#  [3436,
#   614,
#   679,
#   216,
#   394,
#   36,
#   2401,
#   2149,
#   3854,
#   3132,
#   962,
#   2995,
#   931,
#   1029,
#   394,
#   1467,
#   3885,
#   2119,
#   1626,
#   1330,
#   2145,
#   3961,
#   854],
#  [581,
#   2085,
#   103,
#   2119,
#   4183,
#   4631,
#   845,
#   4575,
#   2390,
#   3447,
#   216,
#   988,
#   2995,
#   3875,
#   4662,
#   192,
#   2822,
#   1494,
#   1034],
#  [882,
#   3903,
#   49,
#   123,
#   2906,
#   4916,
#   931,
#   4917,
#   2145,
#   2119,
#   3922,
#   1330,
#   2145,
#   4211,
#   3524,
#   1676,
#   3053,
#   2318,
#   2319,
#   2617],
#  [4469,
#   3885,
#   274,
#   4752,
#   725,
#   883,
#   325,
#   602,
#   3696,
#   3716,
#   4679,
#   533,
#   3422,
#   1921],
#  [4556,
#   2128,
#   4489,
#   2119,
#   3911,
#   4575,
#   4081,
#   1957,
#   2995,
#   190,
#   1842,
#   3488,
#   1855,
#   4556,
#   323,
#   4969,
#   2008,
#   2156,
#   1333,
#   4800,
#   1333],
#  [602,
#   1084,
#   2893,
#   2145,
#   2156,
#   931,
#   2210,
#   2700,
#   1044,
#   3254,
#   4743,
#   3079,
#   2960,
#   2145,
#   2156,
#   1705,
#   1506,
#   3923],
#  [3310, 553, 3021, 4611, 1128, 1730, 2099, 4611, 3798, 4366, 2322, 532, 3455],
#  [4804,
#   4994,
#   1996,
#   1365,
#   3985,
#   3577,
#   2736,
#   868,
#   1624,
#   3109,
#   4994,
#   3985,
#   1365,
#   1996,
#   3577],
#  [4958,
#   2145,
#   4611,
#   3436,
#   2375,
#   2713,
#   579,
#   3310,
#   1076,
#   2058,
#   240,
#   1907,
#   2565,
#   3579,
#   3725,
#   3378,
#   4372],
#  [718,
#   462,
#   1203,
#   216,
#   4025,
#   10,
#   4146,
#   1452,
#   2750,
#   3885,
#   1380,
#   3646,
#   4638,
#   1682],
#  [3310, 3310, 3310, 3310, 2699, 538],
#  [4746, 3196, 2126, 2547, 4159, 854, 3573, 4471, 3197, 4588, 79, 1034],
#  [1076, 3466, 1114, 4556, 3483, 2401, 4556, 3436, 2149, 4100, 216, 823, 1915],
#  [4983, 2956, 4478, 370, 2149, 58, 4576, 4087, 921, 1054, 4267],
#  [1361,
#   1467,
#   4109,
#   2145,
#   3961,
#   1084,
#   2145,
#   2282,
#   1937,
#   2649,
#   2298,
#   3132,
#   3479,
#   3626,
#   2401,
#   2119,
#   4327],
#  [3692, 2603, 3240, 4081, 3196, 2442, 994, 216, 426],
#  [2124, 2119, 752, 123, 4590, 1534, 4294, 3257, 2849],
#  [2149, 4872, 4896, 1467, 2965, 1714, 3, 931, 647],
#  [3885,
#   3436,
#   1114,
#   3739,
#   4087,
#   3134,
#   1960,
#   1683,
#   1114,
#   3800,
#   3885,
#   1960,
#   1307],
#  [1306,
#   4991,
#   343,
#   4611,
#   1037,
#   142,
#   883,
#   4991,
#   2995,
#   4611,
#   1037,
#   3433,
#   3716,
#   725,
#   4611,
#   4701,
#   3716,
#   2145,
#   3021,
#   4933,
#   4611,
#   4413],
#  [3466, 2652, 2374, 3466, 2652, 504, 2059],
#  [3310, 1467, 2099, 2149, 4296, 3132, 2322, 2382, 1862, 3137, 605, 3160, 4727],
#  [4912, 4305, 4081, 3988, 3766, 2150, 3774],
#  [3310,
#   3310,
#   3310,
#   2294,
#   4969,
#   2414,
#   1005,
#   1505,
#   1784,
#   4001,
#   2145,
#   3021,
#   70,
#   3194,
#   1332,
#   1855,
#   3887],
#  [4900,
#   385,
#   3466,
#   4709,
#   1505,
#   3330,
#   3310,
#   4738,
#   3132,
#   3310,
#   2549,
#   2655,
#   86,
#   4228],
#  [2149,
#   868,
#   2099,
#   3310,
#   911,
#   1467,
#   2222,
#   2363,
#   2037,
#   1506,
#   1878,
#   3953,
#   175,
#   4949,
#   3196,
#   2208,
#   730],
#  [2574,
#   2210,
#   4611,
#   4356,
#   2995,
#   2674,
#   4679,
#   3641,
#   4008,
#   3799,
#   44,
#   184,
#   3642,
#   3971,
#   2198,
#   235,
#   2756],
#  [529, 1413, 4131, 94, 1114, 2326, 1413, 379, 2660, 3488],
#  [3466, 2652, 4978, 3466, 2652, 504, 2059],
#  [3310,
#   2897,
#   4985,
#   2898,
#   1923,
#   1397,
#   4081,
#   4548,
#   2945,
#   1923,
#   1136,
#   2906,
#   555,
#   2995,
#   1637],
#  [1626, 2850, 2145, 1036, 883, 459, 3774, 3766, 4772],
#  [1347, 3310, 4556, 91, 4109, 3844, 3471, 72, 2766, 123],
#  [1937, 228, 3765, 1251, 2228],
#  [4927, 4109, 2995, 1110, 931, 2099, 1301],
#  [3196, 1864, 4579, 1247, 2792, 538, 1738, 1114, 237, 3410, 791, 1034],
#  [3310,
#   1435,
#   1114,
#   4021,
#   1330,
#   2972,
#   915,
#   1506,
#   2395,
#   4918,
#   2704,
#   4100,
#   577,
#   3374,
#   4055,
#   808,
#   2018,
#   3100,
#   4770],
#  [2265, 2145, 3550, 2401, 3196, 4740, 4239],
#  [581,
#   72,
#   1978,
#   330,
#   4869,
#   116,
#   1364,
#   409,
#   619,
#   2023,
#   3301,
#   3301,
#   216,
#   608,
#   2736,
#   519,
#   582,
#   192,
#   2822,
#   1494,
#   1151],
#  [3134,
#   4017,
#   123,
#   4611,
#   4087,
#   1114,
#   3132,
#   3196,
#   4947,
#   3903,
#   2149,
#   4912,
#   2766,
#   216,
#   2149,
#   2283,
#   1062,
#   3310,
#   596,
#   1114],
#  [3032, 1244, 168, 4636, 1860],
#  [4021,
#   1467,
#   2119,
#   98,
#   2995,
#   615,
#   3433,
#   2283,
#   2870,
#   1240,
#   216,
#   2995,
#   2149,
#   887,
#   3953,
#   3670,
#   4869,
#   421,
#   3466,
#   1128,
#   4081,
#   2149,
#   1887,
#   4239,
#   3903,
#   538],
#  [605, 490, 1256, 4109, 2611],
#  [3134, 1668, 2145, 175, 3271, 123, 2908, 494, 1288],
#  [3466,
#   2652,
#   3647,
#   2099,
#   1333,
#   4253,
#   3953,
#   3895,
#   2145,
#   3441,
#   2022,
#   4081,
#   2149,
#   4457,
#   1207,
#   2452,
#   2022,
#   2894,
#   1855,
#   4343,
#   2222,
#   1046],
#  [2158,
#   1367,
#   4087,
#   3885,
#   216,
#   3097,
#   4081,
#   3310,
#   803,
#   1679,
#   3374,
#   1037,
#   2845,
#   2124,
#   3885,
#   2149,
#   3994],
#  [1862, 3626, 3132, 4013, 2403, 447, 628, 706, 4468],
#  [3310,
#   656,
#   2145,
#   3961,
#   1855,
#   2149,
#   1185,
#   4004,
#   3132,
#   2149,
#   4977,
#   4081,
#   2131,
#   447,
#   1397,
#   1531,
#   2145,
#   1037,
#   3310,
#   1855,
#   1767],
#  [4933, 1289, 2374, 2401, 3310, 2640, 3893, 4267, 3947, 1326, 1388, 1705],
#  [4927,
#   2145,
#   3493,
#   1948,
#   3196,
#   4785,
#   2995,
#   3466,
#   1948,
#   625,
#   2145,
#   1424,
#   2845,
#   2651,
#   188],
#  [3466, 2652, 294, 3466, 2652, 504, 2059],
#  [989,
#   123,
#   2145,
#   3436,
#   2149,
#   4017,
#   4267,
#   3613,
#   4267,
#   3613,
#   1830,
#   3716,
#   2683,
#   316,
#   2145,
#   1127],
#  [435, 3809, 1506, 2149, 2317, 918, 484, 542, 1491, 2326, 3866, 1144],
#  [2503, 3201, 1467, 2149, 3994, 4837, 2018, 1395, 2870, 525, 3622, 2149, 1771],
#  [2547, 1138, 4795, 3196, 3418, 3655],
#  [2930, 436, 1066, 1213, 1597, 1213, 1597, 1114, 810],
#  [3310,
#   2995,
#   2149,
#   2661,
#   641,
#   2547,
#   4057,
#   647,
#   4081,
#   1786,
#   572,
#   2099,
#   244,
#   59,
#   3716,
#   1452,
#   4952,
#   912,
#   3132,
#   376],
#  [4480, 1828, 883, 4947, 1902, 4563, 1067, 1114, 4860, 4563, 3800],
#  [3790,
#   1316,
#   3901,
#   692,
#   3549,
#   522,
#   4226,
#   175,
#   4701,
#   2145,
#   956,
#   3196,
#   4800,
#   2145,
#   3352,
#   2807,
#   305],
#  [4088, 3164, 3060, 3078, 3228, 3758, 4035, 3364, 562],
#  [3310,
#   2294,
#   481,
#   2119,
#   4743,
#   1191,
#   4611,
#   4087,
#   2145,
#   4136,
#   2099,
#   2145,
#   883,
#   2766,
#   3,
#   1207,
#   989,
#   123,
#   1513,
#   3637,
#   1817],
#  [4057,
#   2265,
#   2145,
#   3961,
#   711,
#   883,
#   641,
#   1467,
#   3124,
#   3425,
#   934,
#   3425,
#   570,
#   4462,
#   3818,
#   4155],
#  [3466, 2652, 169, 3466, 2652, 504, 2059],
#  [3749,
#   583,
#   1855,
#   306,
#   3677,
#   1607,
#   228,
#   2996,
#   2945,
#   61,
#   1855,
#   2022,
#   1461,
#   2689],
#  [2406, 33, 577, 4674, 99, 1362, 2518],
#  [4087,
#   4611,
#   18,
#   3903,
#   1128,
#   4537,
#   2149,
#   4087,
#   1572,
#   1855,
#   4611,
#   1034,
#   3579,
#   4355,
#   693],
#  [3310,
#   3310,
#   1572,
#   2149,
#   1584,
#   4665,
#   4253,
#   2582,
#   1203,
#   4611,
#   2961,
#   2987,
#   2401,
#   668,
#   278,
#   2995,
#   1768,
#   4253,
#   533,
#   2401,
#   3427],
#  [989, 123, 2145, 3436, 538],
#  [4983,
#   1247,
#   3885,
#   2401,
#   883,
#   1016,
#   4021,
#   3886,
#   4611,
#   2128,
#   1066,
#   4872,
#   2119,
#   3879,
#   216,
#   1034],
#  [3310, 1818, 2398, 491, 2398, 4093, 1960],
#  [1948,
#   2145,
#   4996,
#   2149,
#   1364,
#   3025,
#   2149,
#   41,
#   1761,
#   4418,
#   435,
#   874,
#   216,
#   435,
#   4110,
#   1046,
#   3310,
#   3818],
#  [1886, 2893, 986, 854, 3530, 3668, 4587],
#  [553, 2458, 2945, 3148, 1136, 4537, 1626],
#  [3310, 3466, 2996, 2995, 1612],
#  [1114, 4021, 1830, 3209, 3758, 215, 2082, 3118, 3829, 373, 2478],
#  [3310,
#   1047,
#   1597,
#   4279,
#   1215,
#   2145,
#   3483,
#   3196,
#   3824,
#   2995,
#   2156,
#   648,
#   4081,
#   3259,
#   1467,
#   4021,
#   692,
#   1018,
#   4933,
#   762,
#   2279,
#   1818,
#   3622],
#  [3310,
#   4927,
#   1183,
#   4081,
#   4017,
#   4496,
#   1855,
#   2149,
# ...
#   3716,
#   2820,
#   4081,
#   4611,
#   2145,
#   1431,
#   216,
#   2322,
#   2916,
#   3374,
#   2656,
#   3472,
#   3524,
#   3716,
#   4611,
#   3404,
#   3310,
#   1034],
#  [1076, 3466, 1114, 4556, 3483, 2401, 4556, 3436, 2149, 4100, 216, 823, 1915],
#  [4473, 2651, 4109, 188, 3015, 4173, 323, 2149, 3765, 1029, 962, 3395],
#  [3021, 2987, 3132, 481, 4226, 4611, 824, 4475],
#  [1981, 2874, 919, 4132, 3449, 3658, 209, 1578, 2061, 1534],
#  [500, 2969, 3356, 3874, 3121, 3813, 3283, 3310],
#  [3310, 3310, 2870, 2149, 1332, 4087, 2678, 435, 4551, 239],
#  [4256, 2145, 3456, 4081, 3196, 4929, 2220, 3588],
#  [3109,
#   1467,
#   3196,
#   36,
#   1114,
#   3466,
#   608,
#   3885,
#   3961,
#   3356,
#   572,
#   3109,
#   4226,
#   175,
#   1128,
#   4537,
#   3466,
#   2652,
#   1114,
#   439,
#   2877],
#  [3310, 2659, 3499, 4052, 2845, 690, 2995, 2945, 1310, 1948, 1855, 931, 1738],
#  [4983,
#   4611,
#   4701,
#   2145,
#   3961,
#   3961,
#   4823,
#   2145,
#   2149,
#   2079,
#   3716,
#   1467,
#   2119,
#   4000,
#   2145,
#   2589,
#   2750,
#   3348,
#   1203,
#   1185,
#   3041],
#  [1505, 2119, 3668, 4947, 4927, 33, 423, 2145, 3961, 216, 3716, 767],
#  [2149, 2565, 693, 1681, 2145, 3310, 3310, 3310, 504],
#  [4611,
#   4701,
#   2145,
#   4143,
#   2119,
#   2551,
#   4889,
#   1730,
#   3670,
#   4379,
#   3598,
#   2149,
#   556,
#   3132,
#   2149,
#   1830,
#   2115,
#   2149,
#   2849,
#   4811,
#   2253],
#  [2659, 4122, 216, 1471, 718, 1047, 3986, 3514, 103, 2149, 1733],
#  [3310, 2119, 4898, 3132, 435, 3713, 4087, 4259],
#  [4109, 2145, 2210, 3310, 2906, 4105, 4118, 4362],
#  [3310, 1177, 3158, 2145, 175, 4109, 2099, 1396, 3109, 1090, 4537, 175, 4338],
#  [4743, 734, 2145, 1003, 2119, 2699, 2552, 234, 2955, 1557, 1091],
#  [581,
#   500,
#   3629,
#   3084,
#   2938,
#   2701,
#   4410,
#   1103,
#   4739,
#   2736,
#   128,
#   192,
#   2822,
#   1494,
#   1151],
#  [3109,
#   3953,
#   1333,
#   1790,
#   3353,
#   2452,
#   4081,
#   2201,
#   2796,
#   579,
#   2086,
#   2145,
#   4207,
#   3604,
#   2016,
#   3248,
#   1805,
#   2957],
#  [854, 3151, 4081, 3678, 1563, 1855, 2493, 4593, 537, 1900, 3538],
#  [3310, 3310, 3310, 874, 4109, 218, 816, 3477, 2987, 3840, 3121],
#  [3310, 3310, 3310, 3310, 3310, 3310, 3310, 3310, 4958, 1864],
#  [2659, 2149, 2023, 3132, 976, 175, 98, 2562, 3494, 1349, 1783, 3099],
#  [216,
#   2099,
#   3288,
#   2236,
#   2262,
#   2236,
#   3772,
#   2987,
#   2119,
#   956,
#   2145,
#   4869,
#   3115,
#   1589,
#   3550],
#  [931, 4034, 1357, 931, 2149, 690, 1855, 508, 3400],
#  [4109,
#   1769,
#   572,
#   4109,
#   2897,
#   3947,
#   3436,
#   2870,
#   4087,
#   2297,
#   3132,
#   2965,
#   2131,
#   3247,
#   1860,
#   3189],
#  [1084, 2133, 251, 175, 1621, 2494, 98],
#  [3021,
#   3885,
#   3466,
#   4806,
#   3021,
#   3885,
#   3696,
#   2119,
#   2387,
#   216,
#   2119,
#   3971,
#   2892,
#   2995,
#   4372,
#   2845,
#   3613,
#   216,
#   2149,
#   4660,
#   1051,
#   2845,
#   1280,
#   4081,
#   1992,
#   2125,
#   434],
#  [481, 2119, 1614, 1450, 175, 2321, 3885, 4021, 2050, 2426, 4546, 3310, 3310],
#  [2023,
#   483,
#   2145,
#   1923,
#   2257,
#   435,
#   508,
#   4146,
#   1467,
#   1859,
#   508,
#   400,
#   876,
#   3228,
#   3310,
#   1778,
#   2119,
#   3310],
#  [3310, 3109, 1467, 969, 2172, 3242, 2145, 1273, 4244, 2918],
#  [1136, 2906, 4753, 1783, 2995, 3, 937, 1039, 818],
#  [18,
#   968,
#   4226,
#   1261,
#   1730,
#   2222,
#   2411,
#   3472,
#   274,
#   1645,
#   4081,
#   2411,
#   3472,
#   228,
#   994,
#   2149,
#   1876,
#   1034],
#  [1084,
#   2145,
#   508,
#   931,
#   4034,
#   1105,
#   2281,
#   2149,
#   3281,
#   1005,
#   373,
#   2995,
#   608,
#   1565,
#   3436,
#   2149,
#   1005,
#   3903,
#   3197,
#   2867,
#   2875,
#   1783],
#  [4899,
#   3255,
#   2262,
#   3255,
#   4081,
#   4611,
#   2145,
#   3483,
#   216,
#   2149,
#   4219,
#   3132,
#   3197,
#   868,
#   2145,
#   3021,
#   216,
#   4021,
#   499],
#  [2049,
#   4933,
#   2945,
#   3444,
#   72,
#   3313,
#   1880,
#   2945,
#   4087,
#   1443,
#   2723,
#   2945,
#   4087,
#   1417,
#   3132,
#   72,
#   4904],
#  [3310, 3466, 3163, 4611, 4709, 2856, 2703, 2099, 2710, 1801],
#  [2236, 219, 2511, 2995, 2047, 4267, 2119, 3764, 3024, 4522, 2732],
#  [346,
#   312,
#   902,
#   2119,
#   108,
#   555,
#   3132,
#   2119,
#   1862,
#   1002,
#   2099,
#   602,
#   3961,
#   3248,
#   793,
#   2840,
#   1730,
#   4021,
#   4253],
#  [4923,
#   1855,
#   2149,
#   1862,
#   3310,
#   2369,
#   854,
#   4265,
#   2945,
#   1128,
#   793,
#   3987,
#   2145,
#   2488,
#   2149,
#   4003,
#   4087,
#   738,
#   2995,
#   1128,
#   4743],
#  [422, 3638, 4966, 854, 3310, 4673, 422, 1364, 2272, 4147, 3073],
#  [3310, 2149, 2172, 3132, 2100, 3196, 2543, 3196, 75, 3196, 4939, 4017, 2192],
#  [3310,
#   2360,
#   2145,
#   2149,
#   87,
#   1855,
#   883,
#   1862,
#   752,
#   1280,
#   216,
#   2543,
#   915,
#   2145,
#   2149,
#   3688,
#   4239,
#   484],
#  [3466, 2693, 2149, 2192, 4933, 3196, 538, 232, 1937],
#  [1862, 499, 2995, 762, 4000],
#  [3310,
#   4893,
#   435,
#   1294,
#   410,
#   2188,
#   3719,
#   3310,
#   4081,
#   4085,
#   343,
#   2087,
#   1855,
#   2699,
#   1239],
#  [1668, 3725, 2326, 1938, 1855, 1071, 3132, 967, 1684],
#  [3310,
#   344,
#   2149,
#   4665,
#   4253,
#   4747,
#   2149,
#   4112,
#   3132,
#   2429,
#   4537,
#   1842,
#   4452,
#   1708,
#   2429,
#   2659,
#   3772,
#   3990,
#   2145,
#   3961,
#   1730],
#  [3310,
#   1771,
#   1855,
#   2119,
#   1977,
#   544,
#   491,
#   2257,
#   2647,
#   3310,
#   214,
#   1364,
#   216,
#   2840,
#   70,
#   3282],
#  [3310, 4933, 1467, 4021, 4259, 2145, 4624],
#  [4457, 254, 3785, 4232, 2203, 2259, 1948, 577, 738, 3690, 1280, 1534],
#  [3466, 2973, 2119, 3310, 4146, 1506, 3310, 3968, 4731, 2043, 2987],
#  [3310,
#   4109,
#   462,
#   2149,
#   648,
#   3310,
#   231,
#   3196,
#   429,
#   3310,
#   1467,
#   3310,
#   586,
#   975],
#  [3310, 2656, 216, 1139],
#  [481, 2222, 2556, 3369, 43, 3107, 3729],
#  [2294, 4429, 3418, 2426, 973, 973, 2995, 3502, 996, 2156, 1948],
#  [1668,
#   1245,
#   3624,
#   2906,
#   2099,
#   1791,
#   1662,
#   1136,
#   2325,
#   216,
#   2429,
#   1855,
#   4896,
#   4865,
#   3109,
#   1467,
#   2119,
#   1010,
#   4950],
#  [3976, 4175, 2135, 4252, 4239, 1832, 310],
#  [888, 3196, 4542, 4081, 3196, 1082, 3961, 4312, 3890],
#  [1118,
#   3255,
#   2262,
#   3255,
#   4081,
#   4611,
#   2145,
#   3483,
#   216,
#   2149,
#   4219,
#   3132,
#   3197,
#   868,
#   2145,
#   3021,
#   216,
#   4021,
#   734,
#   4611],
#  [3893,
#   4253,
#   3132,
#   690,
#   1836,
#   2099,
#   4087,
#   2893,
#   2145,
#   1948,
#   2119,
#   752,
#   1862,
#   1280,
#   4021,
#   994,
#   3630],
#  [3310,
#   441,
#   3132,
#   2564,
#   4081,
#   4727,
#   2119,
#   2540,
#   2145,
#   1045,
#   1005,
#   846,
#   3661,
#   3310,
#   3310],
#  [4034, 2969, 3310, 3809, 2416, 1005, 3466, 1114, 883, 3222, 572, 1443, 3310],
#  [1626,
#   2145,
#   2156,
#   4927,
#   2649,
#   3491,
#   2716,
#   2906,
#   1280,
#   1855,
#   883,
#   1923,
#   803,
#   1310,
#   1461,
#   2145,
#   2149,
#   690,
#   1467,
#   791,
#   1537],
#  [2945,
#   1505,
#   4412,
#   779,
#   579,
#   2149,
#   1783,
#   2133,
#   1467,
#   1897,
#   614,
#   3008,
#   2145,
#   2169,
#   3524,
#   394,
#   2145,
#   2054,
#   2845],
#  [3283, 312, 1624, 630, 3283, 3188, 1547, 278, 2162, 3134, 2458, 445],
#  [1905, 4791, 4488],
#  [3471, 2987, 2192, 3197, 1830, 2476],
#  [2149,
#   4059,
#   3132,
#   2119,
#   3134,
#   4813,
#   1467,
#   3436,
#   1730,
#   3486,
#   1185,
#   1332,
#   182,
#   3679,
#   2995,
#   185,
#   2133,
#   2952],
#  [2034,
#   2995,
#   3085,
#   4087,
#   3885,
#   4912,
#   538,
#   3436,
#   2149,
#   945,
#   3466,
#   1505,
#   2023,
#   1624,
#   2145,
#   1948,
#   3085,
#   2401,
#   314,
#   1171,
#   265],
#  [2264, 2870, 3163, 4109, 279, 2086, 2473, 3863, 1034],
#  [22, 2730, 2743, 4203, 2914],
#  [2047, 2149, 3626, 3471, 411, 2851, 2771, 4013, 2069, 3474, 4523],
#  [713, 216, 2150, 4, 962, 1182, 1899, 251, 1110, 3453],
#  [2119, 3529, 1467, 462, 2119, 3120, 4853, 889, 152, 1119, 3130, 2388],
#  [4482, 2970, 3326, 2195, 2473, 782, 3257, 2557, 4482, 3758, 3656],
#  [3310, 4136, 3953, 2680, 4239, 3733, 3105, 3078, 121, 3818],
#  [575, 427, 1260, 4567, 4498, 2145, 4972],
#  [3481,
#   4742,
#   1903,
#   1310,
#   2380,
#   4575,
#   2715,
#   2145,
#   4294,
#   3510,
#   1855,
#   3555,
#   2203,
#   4571,
#   795,
#   1116],
#  [1675,
#   2288,
#   2149,
#   2282,
#   3132,
#   2119,
#   346,
#   4648,
#   346,
#   3866,
#   346,
#   121,
#   2995,
#   2119,
#   4743,
#   4200,
#   1277,
#   1886],
#  [1031, 4021, 1467, 2149, 4912, 439, 584, 572, 1051, 4056],
#  [3196, 312, 2874, 2022, 1037, 1675, 3961, 2149, 3994, 3374, 3196, 601, 1498],
#  [1076, 3466, 1114, 4556, 3483, 2401, 4556, 3436, 2149, 4100, 216, 823, 1915],
#  [935, 3173, 550, 2145, 1889, 216, 1855, 2149, 1794, 417],
#  [3310,
#   3820,
#   3210,
#   606,
#   3466,
#   3181,
#   2616,
#   4081,
#   4951,
#   4081,
#   296,
#   1957,
#   3109,
#   3150,
#   1557],
#  [1615,
#   1411,
#   2145,
#   13,
#   2149,
#   36,
#   4478,
#   2345,
#   4081,
#   1695,
#   1312,
#   2023,
#   4259,
#   4021,
#   2061,
#   1485],
#  [4410, 912, 2995, 1526, 1673, 3677],
#  [3310,
#   3310,
#   3109,
#   3953,
#   2145,
#   338,
#   4818,
#   931,
#   2149,
#   4477,
#   3132,
#   435,
#   2997,
#   2124,
#   931,
#   3436,
#   2119,
#   2546,
#   2018,
#   4740,
#   3281,
#   1092],
#  [1332,
#   1984,
#   3903,
#   3477,
#   4216,
#   2119,
#   3359,
#   4366,
#   2945,
#   3021,
#   4109,
#   4216,
#   3477,
#   3953,
#   382,
#   3903,
#   1034],
#  [2124, 2119, 4743, 123, 2145, 2659, 3961, 1784, 572, 1290, 810, 4827],
#  [1505, 2119, 3134, 4958, 1742, 2676, 2665, 4958, 2150, 1114],
#  [3466,
#   1066,
#   1856,
#   13,
#   1675,
#   2637,
#   4216,
#   1185,
#   1332,
#   3619,
#   2995,
#   3466,
#   3099,
#   1310,
#   1291,
#   3159],
#  [3196, 1668, 3765, 3624, 4001, 3029],
#  [3474, 4155, 1247, 2706, 1114, 2376, 3074, 1291, 514, 3307, 4947, 3041, 4644],
#  [3134, 989, 123, 967, 2766, 4537, 1114, 45, 3310],
#  [4454, 995, 2124, 3436, 346, 4538, 4087, 4538, 4087],
#  [4947, 1467, 2298, 605, 4081, 3010, 4231, 436, 1114, 4017, 1915, 1614, 2676],
#  [2145,
#   2149,
#   2766,
#   3132,
#   3196,
#   1578,
#   3466,
#   1114,
#   4556,
#   2317,
#   3132,
#   989,
#   2192,
#   2766,
#   3283],
#  [3310,
#   34,
#   3437,
#   1730,
#   3310,
#   1918,
#   4253,
#   2610,
#   3119,
#   3903,
#   2761,
#   1855,
#   4057,
#   2504],
#  [4611,
#   4996,
#   1247,
#   4299,
#   1594,
#   4933,
#   4611,
#   4413,
#   2145,
#   1948,
#   3632,
#   4676,
#   1397,
#   2906,
#   590,
#   216,
#   1915,
#   3903,
#   807],
#  [1265, 1492, 2825, 3109, 2617, 875, 4087, 3134, 875],
#  [3310,
#   4012,
#   2119,
#   1857,
#   2401,
#   2119,
#   636,
#   3498,
#   3132,
#   3307,
#   3025,
#   2022,
#   1663,
#   2507,
#   3753,
#   1114],
#  [1855, 3157, 3283],
#  [3310,
#   3210,
#   3602,
#   2382,
#   4777,
#   3132,
#   3197,
#   789,
#   2568,
#   3797,
#   922,
#   4611,
#   3197,
#   1505,
#   1333,
#   1593,
#   1855,
#   553,
#   288,
#   3017,
#   2145,
#   3962],
#  [807, 883, 4579, 3903, 1632, 579, 4081, 2363, 4740, 251, 4611, 1534, 4263],
#  [1467,
#   3885,
#   2222,
#   2894,
#   478,
#   1467,
#   2000,
#   1332,
#   4827,
#   1855,
#   3472,
#   2145,
#   4008,
#   814,
#   490,
#   2297,
#   4379,
#   4814,
#   2845,
#   838],
#  [3493, 3085, 854, 4769],
#  [3310, 3310, 2995, 3310, 4927, 1855, 3196, 734, 2128, 2870, 2156, 4831, 739],
#  [3310, 3310, 4593, 2972, 4081, 400],
#  [1805,
#   1336,
#   4267,
#   3466,
#   1505,
#   2145,
#   3696,
#   1855,
#   3196,
#   1188,
#   216,
#   2149,
#   646,
#   3132,
#   4110],
#  [3196,
#   2112,
#   694,
#   4267,
#   2145,
#   2149,
#   2867,
#   3132,
#   185,
#   1492,
#   1332,
#   4235,
#   216,
#   2149,
#   1958,
#   216,
#   1029],
#  [2577, 3310, 4686, 2330, 2552, 4837, 3352, 3310],
#  [4109,
#   2870,
#   2490,
#   2119,
#   262,
#   3119,
#   3532,
#   1791,
#   4922,
#   3532,
#   1492,
#   1126,
#   752,
#   3081],
#  [614, 4534, 1037, 1948, 4611, 656, 4081, 2149, 3168, 3595, 1928, 3666, 3664],
#  [3310,
#   2360,
#   2166,
#   762,
#   4098,
#   2169,
#   2897,
#   3622,
#   2401,
#   3310,
#   3209,
#   1170,
#   4081,
#   2149,
#   2974,
#   1162],
#  [2870, 4098, 3716, 3987],
#  [1379, 4182, 3466, 2564, 4611, 3436, 1505, 2119, 752, 4958, 3058, 60, 1247],
#  [3466, 2131, 2996, 2099, 1371, 1861, 4169, 2145, 4021, 3400, 2426, 4077],
#  [581,
#   1014,
#   3629,
#   363,
#   2145,
#   619,
#   4977,
#   2697,
#   1684,
#   3384,
#   1143,
#   2995,
#   4141,
#   2606,
#   192,
#   2822,
#   1494,
#   1151],
#  [553,
#   2897,
#   1280,
#   121,
#   1467,
#   3925,
#   2119,
#   844,
#   262,
#   937,
#   4087,
#   4361,
#   2906,
#   1016],
#  [3134,
#   1668,
#   2145,
#   4253,
#   3132,
#   2149,
#   3144,
#   4854,
#   3550,
#   620,
#   763,
#   1668,
#   1899,
#   1569],
#  [3310, 1240, 883, 4947],
#  [1708,
#   2145,
#   499,
#   2275,
#   588,
#   2145,
#   3961,
#   2589,
#   2115,
#   3514,
#   3525,
#   4904,
#   3474,
#   2535],
#  [3310, 3466, 2731, 2119, 3999, 3106, 3716, 1452, 4081, 2037],
#  [1186, 2013, 1191, 2660, 4239, 3372, 98, 175, 1783, 2326, 4940],
#  [1683, 1683, 2119, 4470, 538, 747, 1683, 2875, 3035, 3134, 4470],
#  [3310,
#   3134,
#   3281,
#   3753,
#   417,
#   2145,
#   3196,
#   2556,
#   967,
#   3310,
#   4768,
#   1598,
#   2484,
#   872,
#   1114],
#  [1937,
#   2119,
#   4772,
#   4413,
#   3466,
#   2731,
#   2119,
#   2245,
#   123,
#   4299,
#   1084,
#   3524,
#   2119,
#   2022,
#   1937,
#   2119,
#   3503,
#   3132,
#   957,
#   2995,
#   2582,
#   1467,
#   789,
#   2857],
#  [3466,
#   1114,
#   4920,
#   2995,
#   4995,
#   3466,
#   1114,
#   2149,
#   1803,
#   3514,
#   2995,
#   3466,
#   1114,
#   2149,
#   734,
#   3466,
#   1128,
#   2747,
#   3520,
#   2401,
#   3287,
#   2995,
#   1583,
#   4930,
#   810],
#  [581, 500, 4232, 1986, 4843, 376, 2999, 619, 3904, 192, 2822, 1494, 1151],
#  [3209, 2401, 3310, 3952],
#  [2124,
#   2222,
#   3211,
#   3131,
#   123,
#   606,
#   123,
#   2995,
#   4170,
#   2401,
#   538,
#   4958,
#   2145,
#   1742,
#   3685,
#   1371],
#  [876,
#   1814,
#   2542,
#   4611,
#   2961,
#   2145,
#   3021,
#   2145,
#   1199,
#   2145,
#   2149,
#   1957,
#   2149,
#   2961,
#   2145,
#   2937,
#   2149,
#   1705,
#   4500],
#  [763,
#   1467,
#   2455,
#   216,
#   4611,
#   636,
#   655,
#   1114,
#   1204,
#   2930,
#   1354,
#   1254,
#   2897,
#   546],
#  [2043,
#   127,
#   3132,
#   3053,
#   3404,
#   4283,
#   1607,
#   3929,
#   1246,
#   3257,
#   1204,
#   882,
#   3132,
#   1316],
#  [4118, 1777, 1877, 395, 3411],
#  [3466,
#   2128,
#   15,
#   3421,
#   2099,
#   228,
#   2501,
#   3078,
#   1467,
#   921,
#   4017,
#   175,
#   3057,
#   3988,
#   3525,
#   1892],
#  [391, 2547, 1784, 2145, 2156, 4109, 4611, 1, 2099, 1992],
#  [4927, 2659, 2222, 947, 2326, 1868, 4239],
#  [3310,
#   608,
#   1316,
#   2347,
#   323,
#   633,
#   608,
#   4021,
#   3520,
#   4493,
#   2150,
#   2913,
#   2995,
#   3201,
#   3520,
#   2902],
#  [3310,
#   3310,
#   1120,
#   4256,
#   2260,
#   2298,
#   3132,
#   2149,
#   736,
#   91,
#   1505,
#   1938,
#   1902,
#   1957,
#   2145,
#   2026,
#   2119,
#   1754,
#   559,
#   3040],
#  [3310, 3471, 2265, 2099, 423, 1378, 2149, 2283, 2333, 2400, 4895, 2924],
#  [3466,
#   3614,
#   4385,
#   3336,
#   4216,
#   4611,
#   1310,
#   3624,
#   1948,
#   883,
#   937,
#   216,
#   2149,
#   2083,
#   1207,
#   2945,
#   3421,
#   4611,
#   1333,
#   2870,
#   1310,
#   2961,
#   4611],
#  [3466, 2652, 4827, 4081, 379, 4827, 504],
#  [2145,
#   1071,
#   2416,
#   3196,
#   4669,
#   123,
#   1902,
#   175,
#   3885,
#   3937,
#   3482,
#   4081,
#   3196,
#   4252,
#   3310,
#   1915,
#   343,
#   3986,
#   3471,
#   1557,
#   1506,
#   61,
#   3903,
#   3466,
#   2947,
#   4996],
#  [752, 3466, 1114, 2025, 2906, 2149, 3257, 3257, 2559],
#  [3310,
#   3364,
#   4531,
#   1817,
#   3466,
#   804,
#   4611,
#   1452,
#   2314,
#   3021,
#   3666,
#   3812,
#   1886,
#   1136,
#   4537,
#   2119,
#   508,
#   4146],
#  [3570, 1201, 2145, 3196, 2951, 4544, 367, 3814, 3310, 3310, 3310, 3310],
#  [3310, 3310, 3310, 3911, 3466, 3624, 1505, 2119, 4900, 3132, 3691, 2651],
#  [734, 2145, 4413, 2149, 123, 2912],
#  [3022, 1531, 2023, 435, 1286, 995, 1114, 3829, 3310, 3310, 3310],
#  [3310,
#   4757,
#   2149,
#   228,
#   4912,
#   1647,
#   4648,
#   725,
#   895,
#   2987,
#   2302,
#   3291,
#   3901,
#   1034],
#  [4021, 2119, 2119, 2972, 4195, 4081, 2504, 264, 4246, 514, 2816],
#  [2195, 906, 3196, 1907],
#  [3537,
#   4537,
#   2061,
#   4482,
#   1114,
#   4537,
#   1240,
#   4947,
#   3758,
#   3766,
#   4590,
#   3225,
#   4194,
#   4940],
#  [1488,
#   3231,
#   2099,
#   344,
#   2314,
#   108,
#   2149,
#   3444,
#   3132,
#   1154,
#   2401,
#   3196,
#   596,
#   4179,
#   1104],
#  [3310, 1310, 2145, 3310, 4200, 4368, 2099, 1493, 3117, 1505, 3516, 3875, 544],
#  [3668, 2322, 3534, 2470, 4735, 892],
#  [3310, 3320, 1705, 1110],
#  [1333,
#   1612,
#   3885,
#   3504,
#   2145,
#   1018,
#   1450,
#   565,
#   1612,
#   3885,
#   1018,
#   481,
#   4983,
#   3466,
#   3421,
#   4611,
#   1333,
#   1612,
#   3885,
#   3504,
#   2145,
#   4556,
#   565,
#   1612,
#   3885,
#   4978,
#   3472,
#   577,
#   3095],
#  [3310,
#   3539,
#   1223,
#   1417,
#   4001,
#   3840,
#   2965,
#   2906,
#   3140,
#   1097,
#   3436,
#   3196,
#   4947,
#   3477],
#  [3395, 1923, 4267, 2145, 387, 2995, 3356, 4239],
#  [4845, 3196, 3541, 1467, 934, 216, 4253, 994],
#  [1692, 3132, 2149, 4254, 3811, 2296, 2623, 1708, 3785],
#  [1149, 3541, 312, 2020, 112, 2894, 3863],
#  [320, 3716, 3436, 4122, 1311, 3310],
#  [2133, 1203, 3446, 1980, 490, 3213, 706, 4010],
#  [4087, 4611, 1443, 490, 2659, 2106, 2145, 3961, 1427, 3301, 1214, 4772, 1058],
#  [3466,
#   3493,
#   2528,
#   2119,
#   734,
#   553,
#   2145,
#   3620,
#   1594,
#   2752,
#   4611,
#   346,
#   1336,
#   3716,
#   736,
#   2018,
#   4524,
#   2802],
#  [3310, 481, 2119, 3809, 1495, 1711, 4266, 1410, 2361, 2782, 4489, 2362],
#  [1505,
#   4611,
#   3696,
#   216,
#   883,
#   2821,
#   2303,
#   4983,
#   4611,
#   3225,
#   3021,
#   3716,
#   2995,
#   1354,
#   4109,
#   2870,
#   2128,
#   2210,
#   481,
#   4226,
#   4611,
#   1783,
#   4691],
#  [3310,
#   228,
#   1778,
#   216,
#   4947,
#   2403,
#   2840,
#   1397,
#   2906,
#   2119,
#   4252,
#   854,
#   2401,
#   3196,
#   1227,
#   2256],
#  ...]

# %%
df.head()
# Out:
#    id  label                                              tweet  tweet_length  \
# 0   1      0   @user when a father is dysfunctional and is s...           102
# 1   2      0  @user @user thanks for #lyft credit i can't us...           122
# 2   3      0                                bihday your majesty            21
# 3   4      0  #model   i love u take with u all the time in ...            86
# 4   5      0             factsguide: society now    #motivation            39
#
#                                      processed_tweet
# 0  user father dysfunctional selfish drags kids d...
# 1  user user thanks lyft credit ca use cause offe...
# 2                                     bihday majesty
# 3                           model love u take u time
# 4                      factsguide society motivation

# %%
sent_lenght=20
embedded_docs=pad_sequences(one_hot_rep,padding='pre',maxlen=sent_lenght)
embedded_docs
# Out:
# array([[   0,    0, 3310, ..., 3356, 4368, 1016],
#        [   0, 3310, 3310, ..., 1564, 4710,  455],
#        [   0,    0,    0, ..., 1668,  883, 4176],
#        ...,
#        [   0,    0,    0, ...,   61, 1467, 3764],
#        [   0,    0,    0, ..., 4740, 4568,  505],
#        [   0,    0,    0, ..., 4081, 4611, 2473]])

# %% [markdown]
# ### <font color = #27C3E5> 2.4: </font> <font color = #41EA46>  Split the Dataset </font>

# %%
X_final=np.array(embedded_docs)
y_final=np.array(y)
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size=0.2, random_state=42)

# %%
y_final
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
print("X_train", X_train.shape)
print("y_train", y_train.shape)
# Out:
# X_train (25569, 20)
# y_train (25569,)

# %%
print("X_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# X_test (6393, 20)
# y_test (6393,)

# %%
X_train.shape[1]
# Out:
# 20

# %% [markdown]
# <img style="width:70px; height:70px; float:left;" src="https://www.pinclipart.com/picdir/big/163-1639462_work-pc-sticker-pc-gif-transparent-clipart.png"><img style="width:70px; height:70px; float:right;" src="https://www.pinclipart.com/picdir/big/163-1639462_work-pc-sticker-pc-gif-transparent-clipart.png"><h2 style="background-color:black; color:white; text-align:center;"><b><i>Part 3: Build the Rnn with LSTM </i></b></h2>

# %% [markdown]
# ### <font color = #27C3E5> 3.1: </font> <font color = #41EA46>   Long Short Term Memory </font>

# %%
#### Early stopping
es=EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=0,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %%
embedding_vector_features=40 ### each word will represent in a vector size of 40
model=Sequential()
model.add(Embedding(voc_size,embedding_vector_features,input_length=sent_lenght))
model.add(Dropout(0.3))
model.add(LSTM(100))
model.add(Dropout(0.3))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# #### <font color = Yellow>3.1.3: Compile the Model

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #### <font color = Yellow>3.2.4: Fit the Training Data into Model

# %%
history=model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test),callbacks=[es])
# Out:
# Epoch 1/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9249 - loss: 0.2837 - val_accuracy: 0.9484 - val_loss: 0.1503
# Epoch 2/50
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9597 - loss: 0.1169 - val_accuracy: 0.9490 - val_loss: 0.1529

# %% [markdown]
# #### <font color = Yellow>3.2.5: Predict the Train and Test Data

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
# Out:
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# #### <font color = Yellow>3.2.6: Print the accuracy and Cm

# %%
y_pred_train_classes = (y_pred_train > 0.5).astype(int)
y_pred_test_classes = (y_pred_test > 0.5).astype(int)

# %%
conf_matrix_train = confusion_matrix(y_train, y_pred_train_classes)
print("Confusion Matrix (Training Data):")
print(conf_matrix_train)
# Out:
# Confusion Matrix (Training Data):
# [[23657   126]
#  [  771  1015]]

# %%
conf_matrix_test = confusion_matrix(y_test, y_pred_test_classes)
print("Confusion Matrix (Test Data):")
print(conf_matrix_test)
# Out:
# Confusion Matrix (Test Data):
# [[5883   54]
#  [ 272  184]]

# %%
train_accuracy_manual = accuracy_score(y_train, y_pred_train_classes)
test_accuracy_manual = accuracy_score(y_test, y_pred_test_classes)

print(f"Manual Training Accuracy: {train_accuracy_manual:.4f}")
print(f"Manual Test Accuracy: {test_accuracy_manual:.4f}")
# Out:
# Manual Training Accuracy: 0.9649
# Manual Test Accuracy: 0.9490

# %%
class_report_train = classification_report(y_train, y_pred_train_classes)
print("Classification Report (Training Data):")
print(class_report_train)
# Out:
# Classification Report (Training Data):
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     23783
#            1       0.89      0.57      0.69      1786
#
#     accuracy                           0.96     25569
#    macro avg       0.93      0.78      0.84     25569
# weighted avg       0.96      0.96      0.96     25569

# %%
class_report_test = classification_report(y_test, y_pred_test_classes)
print("Classification Report (Test Data):")
print(class_report_test)
# Out:
# Classification Report (Test Data):
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      5937
#            1       0.77      0.40      0.53       456
#
#     accuracy                           0.95      6393
#    macro avg       0.86      0.70      0.75      6393
# weighted avg       0.94      0.95      0.94      6393

# %%
train_accuracy_manual = accuracy_score(y_train, y_pred_train_classes)
test_accuracy_manual = accuracy_score(y_test, y_pred_test_classes)

print(f"Manual Training Accuracy: {train_accuracy_manual:.4f}")
print(f"Manual Test Accuracy: {test_accuracy_manual:.4f}")
# Out:
# Manual Training Accuracy: 0.9649
# Manual Test Accuracy: 0.9490
